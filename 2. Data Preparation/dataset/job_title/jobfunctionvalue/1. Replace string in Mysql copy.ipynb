# %%
# Import
import sys
sys.path.append('../../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobfunctionvalue"    
    # -------------------------------------------------- 
    space = "  __"
    # --------------------------------------------------  
    old_value    = '"name":"' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":501,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = '","children":null}' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":130,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = '{"' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":502,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":503,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":504,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":505,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":507,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":508,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":509,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":510,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":511,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":512,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":513,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":514,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":131,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":132,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":133,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":135,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":150,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":180,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":184,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":198,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":107,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":114,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":191,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":192,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":193,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":104,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":111,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":110,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":116,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":117,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":112,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":113,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":115,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":140,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":194,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":196,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":197,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":200,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":195,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":190,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":189,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":188,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":187,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":186,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":185,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":148,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":146,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":137,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":141,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":106,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":101,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":100,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":141,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":106,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":100,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":204,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":199,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":183,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":111,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":181,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":109,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    old_value    = 'code":182,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    old_value    = 'code":108,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":102,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":103,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":202,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":203,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":151,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":149,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":145,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":144,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":143,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":142,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":139,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":105,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":152,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":147,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":138,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":134,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":120,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":119,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":118,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # -------------------------------------------------- 
    old_value    = 'code":121,' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------   
    ####################################################
# Out:
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
#   ____updated_and_clean()
