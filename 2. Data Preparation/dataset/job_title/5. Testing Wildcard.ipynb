# %%
# Import
import sys
sys.path.append('../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "dataset_jobtitle" 
    space = "  __"
    # --------------------------------------------------  
    testing_wildcard(entity, 'id', space) 
    testing_wildcard(entity, 'en', space) 
    # --------------------------------------------------  
    ####################################################
# Out:
#   ____testing_wildcard()
#   ______Select  nama  , id  from dataset_jobtitle where sama_dengan = 1
#   ________Total Row(s) : 27
#   __________count_wildcard()
#   ____________Select  *  from jobtitle where name like '%Barista%'  and jobtitle_id is null
#   ______________Total Row(s) : 82
#   ________________updated_data_val()
#   __________________UPDATE `dataset_jobtitle` SET  `wildcard_id`='82'  WHERE id = '2'
#   __________count_wildcard()
#   ____________Select  *  from jobtitle where name like '%Admin%'  and jobtitle_id is null
#   ______________Total Row(s) : 2294
#   ________________updated_data_val()
#   __________________UPDATE `dataset_jobtitle` SET  `wildcard_id`='2294'  WHERE id = '3'
#   __________count_wildcard()
#   ____________Select  *  from jobtitle where name like '%Marketing%'  and jobtitle_id is null
#   ______________Total Row(s) : 2599
#   ________________updated_data_val()
# ...
