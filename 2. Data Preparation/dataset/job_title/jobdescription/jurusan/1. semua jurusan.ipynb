# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription"  
    name    = "semua jurusan"
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------   
    usia_maksimal(entity, name, space)
    # --------------------------------------------------   
    ####################################################
# Out:
#   ____usia_maksimal()
#   ______Select  fk_id   , name   from jobdescription WHERE `name` LIKE '%semua jurusan%'
#   ________Total Row(s) : 2281
#   __________[1/2281]  #13 __  Keuntungan   Tunjangan Makan  &  Transport  Bonus / Insentif Bulanan  Jenjang Karir   Kualifikasi :   Pendidikan SMA, D3, S1 Semua Jurusan  Memiliki pengalaman menjadi  host live streaming  atau  costumer oriented  lebih diutamakan.  Memiliki kemampuan  public speaking  dan  upselling  yang baik.  Berpenampilan rapi percaya diri, influence dan ceria.  Bersedia bekerja  shifting.   Terbiasa bekerja dengan target, mampu bekerjasama dg tim.   Tugas :   Memasarkan produk melalui live streaming TikTok, Shopee dan Marketplace lainnya sesuai dengan target yang ditentukan  membuat dan upload  short video content  selama 15 menit.  Mengerjakan live sesuai dg set dan arahan yang telah diberikan  "
# ...
