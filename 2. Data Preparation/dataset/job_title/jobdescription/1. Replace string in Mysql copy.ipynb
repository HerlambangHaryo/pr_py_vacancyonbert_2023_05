# %%
# Import
import sys
sys.path.append('../../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription"   
    # -------------------------------------------------- 
    space = "  __"
    # --------------------------------------------------  
    old_value    = '"html":"' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = 'u002F' 
    new_value    = '/'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = 'u003C' 
    new_value    = '<'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = 'u003E' 
    new_value    = '>'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</li>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</ul>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</p>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</ol>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</strong>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</u>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</div>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '<br />' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space)
    # --------------------------------------------------  
    old_value    = '</em>' 
    new_value    = '.'
    updated_and_clean(entity, old_value, new_value, space) 
    # --------------------------------------------------  
    old_value    = ':' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space) 
    # --------------------------------------------------  
    old_value    = '"' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space) 
    # --------------------------------------------------  
    old_value    = '·' 
    new_value    = ''
    updated_and_clean(entity, old_value, new_value, space) 

    
    # --------------------------------------------------   
    ####################################################
# Out:
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '"html":"', '')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, 'u002F', '/')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, 'u003C', '<')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, 'u003E', '>')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</li>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</ul>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</p>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</ol>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</strong>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</u>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</div>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '<br />', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '</em>', '.')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, ':', '')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '"', '')
#   ____updated_and_clean()
#   ______UPDATE `jobdescription` SET  `name`= REPLACE(name, '·', '')
