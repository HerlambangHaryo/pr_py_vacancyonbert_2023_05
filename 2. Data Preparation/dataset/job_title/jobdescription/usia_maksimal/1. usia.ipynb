# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription"  
    name    = "usia"
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------   
    usia(entity, name, space)
    # --------------------------------------------------   
    ####################################################
# Out:
#   ____usia()
#   ______Select  fk_id   , name   from jobdescription WHERE `name` LIKE '% usia %'
#   ________Total Row(s) : 9699
#   __________[1/9699]  #3 _|_ 2 _|_  maksimal 38  _|_ Valid
#   __________[2/9699]  #5 _|_ 2 _|_  maksimal 40  _|_ Valid
#   __________[3/9699]  #11 _|_ 2 _|_  maksimal 30  _|_ Valid
#   __________[4/9699]  #18 _|_ 2 _|_  23 - 25
#   __________[5/9699]  #21 _|_ 2 _|_  25-35
#   __________[6/9699]  #23 _|_ 2 _|_  maksimal 30  _|_ Valid
#   __________[7/9699]  #28 _|_ 2 _|_  antara 25
#   __________[8/9699]  #35 _|_ 2 _|_  maksimal 30  _|_ Valid
#   __________[9/9699]  #42 _|_ 2 _|_  maksimal 35  _|_ Valid
#   __________[10/9699]  #46 _|_ 2 _|_  35
#   __________[11/9699]  #49 _|_ 2 _|_  maksimal 35  _|_ Valid
#   __________[12/9699]  #50 _|_ 2 _|_  minimal 27
#   __________[13/9699]  #56 _|_ 2 _|_  35
#   __________[14/9699]  #57 _|_ 2 _|_  maksimal 27  _|_ Valid
#   __________[15/9699]  #66 _|_ 2 _|_  35
# ...
