# %%
# Import
import sys
sys.path.append('../../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "locations"   
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    distinct_to_datasetX(entity, space)
    # --------------------------------------------------  
    ####################################################
# Out:
#   ____distinct_to_datasetX()
#   ______Select  name   , count(*) as counter   from locations where name is not null and name != 'null' and name != ''  group by name  ORDER BY count(*) desc, name ASC
#   ________Total Row(s) : 229
#   __________[1/229]  #Jakarta Raya
#   __________insert_wo_fk()
#   ____________INSERT INTO `dataset_locations` ( `nama`  ) VALUES (  'Jakarta Raya'  )
#   __________last_id_desc()
#   ____________Select  id   from dataset_locations order by id desc  limit 1
#   ______________Last ID:1
#   __________updated_data_dataset()
#   ____________UPDATE `locations` SET  `name`='1'  WHERE name = 'Jakarta Raya'
#
#
#   __________[2/229]  #Jakarta Selatan
#   __________insert_wo_fk()
#   ____________INSERT INTO `dataset_locations` ( `nama`  ) VALUES (  'Jakarta Selatan'  )
#   __________last_id_desc()
#   ____________Select  id   from dataset_locations order by id desc  limit 1
#   ______________Last ID:2
#   __________updated_data_dataset()
# ...
