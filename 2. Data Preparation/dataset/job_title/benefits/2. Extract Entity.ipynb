# %%
# Import
import sys
sys.path.append('../../../../')
 
from a_models.general import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity              = "working_hours"  
    entity_extract      = "benefits"  
    entity_destination  = "jobtitle"  
    attr                = "working_hours_id"
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    extract_entity(entity, entity_extract, entity_destination, attr, space)
    # --------------------------------------------------   
    ####################################################
# Out:
#   ____extract_entity()
#   ______Select  id   , nama   from dataset_working_hours
#   ________Total Row(s) : 1
#   __________[1/1]  #Waktu Regular, Senin - Jumat
#   __________select_entity()
#   ____________Select  fk_id   , name   from benefits WHERE `name` LIKE '%Waktu Regular, Senin - Jumat%'
#   ______________Total Row(s) : 19039
#   ________________[1/19039]  #1 __ Asuransi Gigi,Tip,Asuransi kesehatan,Penglihatan,Waktu regular, Senin - Jumat,Bisnis (contoh: Kemeja)
#   ________________updated_data_id_from_dataset()
#   __________________UPDATE `jobtitle` SET  `working_hours_id`='1'  WHERE fk_id = '1'
#   ________________[2/19039]  #2 __ Asuransi kesehatan,Waktu regular, Senin - Jumat,Formil (contoh: Kemeja + Dasi)
#   ________________updated_data_id_from_dataset()
#   __________________UPDATE `jobtitle` SET  `working_hours_id`='1'  WHERE fk_id = '2'
#   ________________[3/19039]  #10 __ Waktu regular, Senin - Jumat,Kasual (contoh: Kaos)
# ...
