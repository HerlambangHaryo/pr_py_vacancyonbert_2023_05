# %%
# Import
import mysql.connector  
import time

entity = "salary_type"
# ----------------------------------------------------------   
space = "__"
# ----------------------------------------------------------   
host="localhost"
user="root" 
database="pr_scraping_job_vacancy_indonesia_2023_07"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
# ----------------------------------------------------------   
query = " Select "
query += " fk_id  "  
query += " from " + entity    
query += " order by id desc "   
query += " limit 1 "    
# ----------------------------------------------------------    
mycursor = mydb.cursor()
mycursor.execute(query) 
result_check = mycursor.fetchone()
# ---------------------------------------------------------- 
mycursor.close()
mydb.close()
# ----------------------------------------------------------  
if result_check is not None and len(result_check) > 0:
    last_id = result_check[0]
else: 
    last_id = 0
# ---------------------------------------------------------- 
print("Last ID:" + str(last_id), flush=True) 
# ---------------------------------------------------------- 


# ----------------------------------------------------------   
query = " Select "
query += " scriptx  "  
query += " , id  "  
query += " from jobstreet_raws_2023_07 "     
query += " where id > " + str(last_id)   
query += " order by id asc "     
# query += " limit 10 "     
# ----------------------------------------------------------  
# print(space + query, flush=True)
# ----------------------------------------------------------    
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
mycursor.execute(query)
myresult = mycursor.fetchall()
mycursor.close()
mydb.close()
# ----------------------------------------------------------
for x in myresult:    
    scriptx     = x[0] 
    idx         = x[1] 

    pre_scriptx = scriptx.split('"salary"') 
    pre_scriptx2 = pre_scriptx[1].split('"type":"') 
    pre_scriptx3 = pre_scriptx2[1].split('"') 

    text = pre_scriptx3[0]
    # ------------------------------------------------------ 
    print(str(idx) + " __ " + text, flush=True) 
    # ------------------------------------------------------ 
 
    # ------------------------------------------------------  
    # ------------------------------------------------------ 
    query_commit = "INSERT INTO `"+entity+"`( "
    # ------------------------------------------------------ 
    query_commit += " `fk_id`, " 
    query_commit += " `name` " 
    query_commit += " ) VALUES ( "
    query_commit += " '" + str(idx) + "', "    
    query_commit += ' "' + str(text).replace("'", "\\'") + '" '
    query_commit += " )  " 
    # ------------------------------------------------------ 
    print(space + query_commit, flush=True)
    # ------------------------------------------------------  
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    mycursor.execute(query_commit)
    mydb.commit()     
    # ------------------------------------------------------ 
    mycursor.close()
    mydb.close()
    # ------------------------------------------------------
# Out:
# Last ID:32934
# 32935 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32935',  "monthly"  )
# 32936 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32936',  "monthly"  )
# 32937 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32937',  "monthly"  )
# 32938 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32938',  "monthly"  )
# 32939 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32939',  "monthly"  )
# 32940 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32940',  "monthly"  )
# 32941 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32941',  "monthly"  )
# 32942 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32942',  "monthly"  )
# 32943 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32943',  "monthly"  )
# 32944 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32944',  "monthly"  )
# 32945 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32945',  "monthly"  )
# 32946 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32946',  "monthly"  )
# 32947 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32947',  "monthly"  )
# 32948 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32948',  "monthly"  )
# 32949 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32949',  "monthly"  )
# 32950 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32950',  "monthly"  )
# 32951 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32951',  "monthly"  )
# 32952 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32952',  "monthly"  )
# 32953 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32953',  "monthly"  )
# 32954 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32954',  "monthly"  )
# 32955 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32955',  "monthly"  )
# 32956 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32956',  "monthly"  )
# 32957 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32957',  "monthly"  )
# 32958 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32958',  "monthly"  )
# 32959 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32959',  "monthly"  )
# 32960 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32960',  "monthly"  )
# 32961 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32961',  "monthly"  )
# 32962 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32962',  "monthly"  )
# 32963 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32963',  "monthly"  )
# 32964 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32964',  "monthly"  )
# 32965 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32965',  "monthly"  )
# 32966 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32966',  "monthly"  )
# 32967 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32967',  "monthly"  )
# 32968 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32968',  "monthly"  )
# 32969 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32969',  "monthly"  )
# 32970 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32970',  "monthly"  )
# 32971 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32971',  "monthly"  )
# 32972 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32972',  "monthly"  )
# 32973 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32973',  "monthly"  )
# 32974 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32974',  "monthly"  )
# 32975 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32975',  "monthly"  )
# 32976 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32976',  "monthly"  )
# 32977 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32977',  "monthly"  )
# 32978 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32978',  "monthly"  )
# 32979 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32979',  "monthly"  )
# 32980 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32980',  "monthly"  )
# 32981 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32981',  "monthly"  )
# 32982 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32982',  "monthly"  )
# 32983 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32983',  "monthly"  )
# 32984 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32984',  "monthly"  )
# 32985 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32985',  "monthly"  )
# 32986 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32986',  "monthly"  )
# 32987 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32987',  "monthly"  )
# 32988 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32988',  "monthly"  )
# 32989 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32989',  "monthly"  )
# 32990 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32990',  "monthly"  )
# 32991 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32991',  "monthly"  )
# 32992 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32992',  "monthly"  )
# 32993 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32993',  "monthly"  )
# 32994 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32994',  "monthly"  )
# 32995 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32995',  "monthly"  )
# 32996 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32996',  "monthly"  )
# 32997 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32997',  "monthly"  )
# 32998 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32998',  "monthly"  )
# 32999 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '32999',  "monthly"  )
# 33000 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33000',  "monthly"  )
# 33001 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33001',  "monthly"  )
# 33002 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33002',  "monthly"  )
# 33003 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33003',  "monthly"  )
# 33004 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33004',  "monthly"  )
# 33005 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33005',  "monthly"  )
# 33006 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33006',  "monthly"  )
# 33007 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33007',  "monthly"  )
# 33008 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33008',  "monthly"  )
# 33009 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33009',  "monthly"  )
# 33010 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33010',  "monthly"  )
# 33011 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33011',  "monthly"  )
# 33012 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33012',  "monthly"  )
# 33013 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33013',  "monthly"  )
# 33014 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33014',  "monthly"  )
# 33015 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33015',  "monthly"  )
# 33016 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33016',  "monthly"  )
# 33017 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33017',  "monthly"  )
# 33018 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33018',  "monthly"  )
# 33019 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33019',  "monthly"  )
# 33020 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33020',  "monthly"  )
# 33021 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33021',  "monthly"  )
# 33022 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33022',  "monthly"  )
# 33023 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33023',  "monthly"  )
# 33024 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33024',  "monthly"  )
# 33025 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33025',  "monthly"  )
# 33026 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33026',  "monthly"  )
# 33027 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33027',  "monthly"  )
# 33028 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33028',  "monthly"  )
# 33029 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33029',  "monthly"  )
# 33030 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33030',  "monthly"  )
# 33031 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33031',  "monthly"  )
# 33032 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33032',  "monthly"  )
# 33033 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33033',  "monthly"  )
# 33034 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33034',  "monthly"  )
# 33035 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33035',  "monthly"  )
# 33036 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33036',  "monthly"  )
# 33037 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33037',  "monthly"  )
# 33038 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33038',  "monthly"  )
# 33039 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33039',  "monthly"  )
# 33040 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33040',  "monthly"  )
# 33041 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33041',  "monthly"  )
# 33042 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33042',  "monthly"  )
# 33043 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33043',  "monthly"  )
# 33044 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33044',  "monthly"  )
# 33045 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33045',  "monthly"  )
# 33046 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33046',  "monthly"  )
# 33047 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '
__ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33133',  "monthly"  )
# 33134 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33134',  "monthly"  )
# 33135 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33135',  "monthly"  )
# 33136 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33136',  "monthly"  )
# 33137 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33137',  "monthly"  )
# 33138 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33138',  "monthly"  )
# 33139 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33139',  "monthly"  )
# 33140 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33140',  "monthly"  )
# 33141 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33141',  "monthly"  )
# 33142 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33142',  "monthly"  )
# 33143 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33143',  "monthly"  )
# 33144 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33144',  "monthly"  )
# 33145 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33145',  "monthly"  )
# 33146 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33146',  "monthly"  )
# 33147 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33147',  "monthly"  )
# 33148 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33148',  "monthly"  )
# 33149 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33149',  "monthly"  )
# 33150 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33150',  "monthly"  )
# 33151 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33151',  "monthly"  )
# 33152 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33152',  "monthly"  )
# 33153 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33153',  "monthly"  )
# 33154 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33154',  "monthly"  )
# 33155 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33155',  "monthly"  )
# 33156 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33156',  "monthly"  )
# 33157 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33157',  "monthly"  )
# 33158 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33158',  "monthly"  )
# 33159 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33159',  "monthly"  )
# 33160 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33160',  "monthly"  )
# 33161 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33161',  "monthly"  )
# 33162 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33162',  "monthly"  )
# 33163 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33163',  "monthly"  )
# 33164 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33164',  "monthly"  )
# 33165 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33165',  "monthly"  )
# 33166 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33166',  "monthly"  )
# 33167 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33167',  "monthly"  )
# 33168 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33168',  "monthly"  )
# 33169 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33169',  "monthly"  )
# 33170 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33170',  "monthly"  )
# 33171 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33171',  "monthly"  )
# 33172 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33172',  "monthly"  )
# 33173 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33173',  "monthly"  )
# 33174 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33174',  "monthly"  )
# 33175 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33175',  "monthly"  )
# 33176 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33176',  "monthly"  )
# 33177 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33177',  "monthly"  )
# 33178 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33178',  "monthly"  )
# 33179 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33179',  "monthly"  )
# 33180 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33180',  "monthly"  )
# 33181 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33181',  "monthly"  )
# 33182 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33182',  "monthly"  )
# 33183 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33183',  "monthly"  )
# 33184 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33184',  "monthly"  )
# 33185 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33185',  "monthly"  )
# 33186 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33186',  "monthly"  )
# 33187 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33187',  "monthly"  )
# 33188 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33188',  "monthly"  )
# 33189 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33189',  "monthly"  )
# 33190 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33190',  "monthly"  )
# 33191 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33191',  "monthly"  )
# 33192 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33192',  "monthly"  )
# 33193 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33193',  "monthly"  )
# 33194 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33194',  "monthly"  )
# 33195 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33195',  "monthly"  )
# 33196 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33196',  "monthly"  )
# 33197 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33197',  "monthly"  )
# 33198 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33198',  "monthly"  )
# 33199 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33199',  "monthly"  )
# 33200 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33200',  "monthly"  )
# 33201 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33201',  "monthly"  )
# 33202 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33202',  "monthly"  )
# 33203 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33203',  "monthly"  )
# 33204 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33204',  "monthly"  )
# 33205 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33205',  "monthly"  )
# 33206 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33206',  "monthly"  )
# 33207 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33207',  "monthly"  )
# 33208 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33208',  "monthly"  )
# 33209 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33209',  "monthly"  )
# 33210 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33210',  "monthly"  )
# 33211 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33211',  "monthly"  )
# 33212 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33212',  "monthly"  )
# 33213 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33213',  "monthly"  )
# 33214 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33214',  "monthly"  )
# 33215 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33215',  "monthly"  )
# 33216 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33216',  "monthly"  )
# 33217 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33217',  "monthly"  )
# 33218 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33218',  "monthly"  )
# 33219 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '
__ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33306',  "monthly"  )
# 33307 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33307',  "monthly"  )
# 33308 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33308',  "monthly"  )
# 33309 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33309',  "monthly"  )
# 33310 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33310',  "monthly"  )
# 33311 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33311',  "monthly"  )
# 33312 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33312',  "monthly"  )
# 33313 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33313',  "monthly"  )
# 33314 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33314',  "monthly"  )
# 33315 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33315',  "monthly"  )
# 33316 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33316',  "monthly"  )
# 33317 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33317',  "monthly"  )
# 33318 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33318',  "monthly"  )
# 33319 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33319',  "monthly"  )
# 33320 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33320',  "monthly"  )
# 33321 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33321',  "monthly"  )
# 33322 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33322',  "monthly"  )
# 33323 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33323',  "monthly"  )
# 33324 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33324',  "monthly"  )
# 33325 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33325',  "monthly"  )
# 33326 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33326',  "monthly"  )
# 33327 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33327',  "monthly"  )
# 33328 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33328',  "monthly"  )
# 33329 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33329',  "monthly"  )
# 33330 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33330',  "monthly"  )
# 33331 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33331',  "monthly"  )
# 33332 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33332',  "monthly"  )
# 33333 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33333',  "monthly"  )
# 33334 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33334',  "monthly"  )
# 33335 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33335',  "monthly"  )
# 33336 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33336',  "monthly"  )
# 33337 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33337',  "monthly"  )
# 33338 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33338',  "monthly"  )
# 33339 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33339',  "monthly"  )
# 33340 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33340',  "monthly"  )
# 33341 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33341',  "monthly"  )
# 33342 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33342',  "monthly"  )
# 33343 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33343',  "monthly"  )
# 33344 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33344',  "monthly"  )
# 33345 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33345',  "monthly"  )
# 33346 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33346',  "monthly"  )
# 33347 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33347',  "monthly"  )
# 33348 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33348',  "monthly"  )
# 33349 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33349',  "monthly"  )
# 33350 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33350',  "monthly"  )
# 33351 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33351',  "monthly"  )
# 33352 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33352',  "monthly"  )
# 33353 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33353',  "monthly"  )
# 33354 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33354',  "monthly"  )
# 33355 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33355',  "monthly"  )
# 33356 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33356',  "monthly"  )
# 33357 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33357',  "monthly"  )
# 33358 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33358',  "monthly"  )
# 33359 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33359',  "monthly"  )
# 33360 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33360',  "monthly"  )
# 33361 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33361',  "monthly"  )
# 33362 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33362',  "monthly"  )
# 33363 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33363',  "monthly"  )
# 33364 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33364',  "monthly"  )
# 33365 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33365',  "monthly"  )
# 33366 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33366',  "monthly"  )
# 33367 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33367',  "monthly"  )
# 33368 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33368',  "monthly"  )
# 33369 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33369',  "monthly"  )
# 33370 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33370',  "monthly"  )
# 33371 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33371',  "monthly"  )
# 33372 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33372',  "monthly"  )
# 33373 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33373',  "monthly"  )
# 33374 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33374',  "monthly"  )
# 33375 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33375',  "monthly"  )
# 33376 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33376',  "monthly"  )
# 33377 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33377',  "monthly"  )
# 33378 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33378',  "monthly"  )
# 33379 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33379',  "monthly"  )
# 33380 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33380',  "monthly"  )
# 33381 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33381',  "monthly"  )
# 33382 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33382',  "monthly"  )
# 33383 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33383',  "monthly"  )
# 33384 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33384',  "monthly"  )
# 33385 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33385',  "monthly"  )
# 33386 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33386',  "monthly"  )
# 33387 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33387',  "monthly"  )
# 33388 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33388',  "monthly"  )
# 33389 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33389',  "monthly"  )
# 33390 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33390',  "monthly"  )
# 33391 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33391',  "monthly"  )
# 33392 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33392',  "monthly"  )
# 33393 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33393',  "monthly"  )
# 33394 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33394',  "monthly"  )
# 33395 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33395',  "monthly"  )
# 33396 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33396',  "monthly"  )
# 33397 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33397',  "monthly"  )
# 33398 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33398',  "monthly"  )
# 33399 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33399',  "monthly"  )
# 33400 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33400',  "monthly"  )
# 33401 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33401',  "monthly"  )
# 33402 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33402',  "monthly"  )
# 33403 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33403',  "monthly"  )
# 33404 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '33404',  "monthly"  )
# 33405 __ monthly
# ...
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48517',  "monthly"  )
# 48518 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48518',  "monthly"  )
# 48519 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48519',  "monthly"  )
# 48520 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48520',  "monthly"  )
# 48521 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48521',  "monthly"  )
# 48522 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48522',  "monthly"  )
# 48523 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48523',  "monthly"  )
# 48524 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48524',  "monthly"  )
# 48525 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48525',  "monthly"  )
# 48526 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48526',  "monthly"  )
# 48527 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48527',  "monthly"  )
# 48528 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48528',  "monthly"  )
# 48529 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48529',  "monthly"  )
# 48530 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48530',  "monthly"  )
# 48531 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48531',  "monthly"  )
# 48532 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48532',  "monthly"  )
# 48533 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48533',  "monthly"  )
# 48534 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48534',  "monthly"  )
# 48535 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48535',  "monthly"  )
# 48536 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48536',  "monthly"  )
# 48537 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48537',  "monthly"  )
# 48538 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48538',  "monthly"  )
# 48539 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48539',  "monthly"  )
# 48540 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48540',  "monthly"  )
# 48541 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48541',  "monthly"  )
# 48542 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48542',  "monthly"  )
# 48543 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48543',  "monthly"  )
# 48544 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48544',  "monthly"  )
# 48545 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48545',  "monthly"  )
# 48546 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48546',  "monthly"  )
# 48547 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48547',  "monthly"  )
# 48548 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48548',  "monthly"  )
# 48549 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48549',  "monthly"  )
# 48550 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48550',  "monthly"  )
# 48551 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48551',  "monthly"  )
# 48552 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48552',  "monthly"  )
# 48553 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48553',  "monthly"  )
# 48554 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48554',  "monthly"  )
# 48555 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48555',  "monthly"  )
# 48556 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48556',  "monthly"  )
# 48557 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48557',  "monthly"  )
# 48558 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48558',  "monthly"  )
# 48559 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48559',  "monthly"  )
# 48560 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48560',  "monthly"  )
# 48561 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48561',  "monthly"  )
# 48562 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48562',  "monthly"  )
# 48563 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48563',  "monthly"  )
# 48564 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48564',  "monthly"  )
# 48565 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48565',  "monthly"  )
# 48566 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48566',  "monthly"  )
# 48567 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48567',  "monthly"  )
# 48568 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48568',  "monthly"  )
# 48569 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48569',  "monthly"  )
# 48570 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48570',  "monthly"  )
# 48571 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48571',  "monthly"  )
# 48572 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48572',  "monthly"  )
# 48573 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48573',  "monthly"  )
# 48574 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48574',  "monthly"  )
# 48575 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48575',  "monthly"  )
# 48576 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48576',  "monthly"  )
# 48577 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48577',  "monthly"  )
# 48578 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48578',  "monthly"  )
# 48579 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48579',  "monthly"  )
# 48580 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48580',  "monthly"  )
# 48581 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48581',  "monthly"  )
# 48582 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48582',  "monthly"  )
# 48583 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48583',  "monthly"  )
# 48584 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48584',  "monthly"  )
# 48585 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48585',  "monthly"  )
# 48586 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48586',  "monthly"  )
# 48587 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48587',  "monthly"  )
# 48588 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48588',  "monthly"  )
# 48589 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48589',  "monthly"  )
# 48590 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48590',  "monthly"  )
# 48591 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48591',  "monthly"  )
# 48592 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48592',  "monthly"  )
# 48593 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48593',  "monthly"  )
# 48594 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48594',  "monthly"  )
# 48595 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48595',  "monthly"  )
# 48596 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48596',  "monthly"  )
# 48597 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48597',  "monthly"  )
# 48598 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48598',  "monthly"  )
# 48599 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48599',  "monthly"  )
# 48600 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48600',  "monthly"  )
# 48601 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48601',  "monthly"  )
# 48602 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48602',  "monthly"  )
# 48603 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48603',  "monthly"  )
# 48604 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48604',  "monthly"  )
# 48605 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48605',  "monthly"  )
# 48606 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48606',  "monthly"  )
# 48607 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48607',  "monthly"  )
# 48608 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48608',  "monthly"  )
# 48609 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48609',  "monthly"  )
# 48610 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48610',  "monthly"  )
# 48611 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48611',  "monthly"  )
# 48612 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48612',  "monthly"  )
# 48613 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48613',  "monthly"  )
# 48614 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48614',  "monthly"  )
# 48615 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48615',  "monthly"  )
# 48616 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48616',  "monthly"  )
# 48617 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48617',  "monthly"  )
# 48618 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48618',  "monthly"  )
# 48619 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48619',  "monthly"  )
# 48620 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48620',  "monthly"  )
# 48621 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48621',  "monthly"  )
# 48622 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48622',  "monthly"  )
# 48623 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48623',  "monthly"  )
# 48624 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48624',  "monthly"  )
# 48625 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48625',  "monthly"  )
# 48626 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48626',  "monthly"  )
# 48627 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48627',  "monthly"  )
# 48628 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48628',  "monthly"  )
# 48629 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48629',  "monthly"  )
# 48630 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48630',  "monthly"  )
# 48631 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48631',  "monthly"  )
# 48632 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48632',  "monthly"  )
# 48633 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48633',  "monthly"  )
# 48634 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48634',  "monthly"  )
# 48635 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48635',  "monthly"  )
# 48636 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48636',  "monthly"  )
# 48637 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48637',  "monthly"  )
# 48638 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48638',  "monthly"  )
# 48639 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48639',  "monthly"  )
# 48640 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48640',  "monthly"  )
# 48641 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48641',  "monthly"  )
# 48642 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48642',  "monthly"  )
# 48643 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48643',  "monthly"  )
# 48644 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48644',  "monthly"  )
# 48645 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48645',  "monthly"  )
# 48646 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48646',  "monthly"  )
# 48647 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48647',  "monthly"  )
# 48648 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48648',  "monthly"  )
# 48649 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48649',  "monthly"  )
# 48650 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48650',  "monthly"  )
# 48651 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48651',  "monthly"  )
# 48652 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48652',  "monthly"  )
# 48653 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48653',  "monthly"  )
# 48654 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48654',  "monthly"  )
# 48655 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48655',  "monthly"  )
# 48656 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48656',  "monthly"  )
# 48657 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48657',  "monthly"  )
# 48658 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48658',  "monthly"  )
# 48659 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48659',  "monthly"  )
# 48660 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48660',  "monthly"  )
# 48661 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48661',  "monthly"  )
# 48662 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48662',  "monthly"  )
# 48663 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48663',  "monthly"  )
# 48664 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48664',  "monthly"  )
# 48665 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48665',  "monthly"  )
# 48666 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48666',  "monthly"  )
# 48667 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48667',  "monthly"  )
# 48668 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48668',  "monthly"  )
# 48669 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48669',  "monthly"  )
# 48670 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48670',  "monthly"  )
# 48671 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48671',  "monthly"  )
# 48672 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48672',  "monthly"  )
# 48673 __ monthly
# __INSERT INTO `salary_type`(  `fk_id`,  `name`  ) VALUES (  '48673',  "monthly"  )
