# %%
# Import
import mysql.connector  
import time

entity = "company_website"
# ----------------------------------------------------------   
space = "__"
# ----------------------------------------------------------   
host="localhost"
user="root" 
database="pr_scraping_job_vacancy_indonesia_2023_07"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
# ----------------------------------------------------------   
query = " Select "
query += " fk_id  "  
query += " from " + entity    
query += " order by id desc "   
query += " limit 1 "    
# ----------------------------------------------------------    
mycursor = mydb.cursor()
mycursor.execute(query) 
result_check = mycursor.fetchone()
# ---------------------------------------------------------- 
mycursor.close()
mydb.close()
# ----------------------------------------------------------  
if result_check is not None and len(result_check) > 0:
    last_id = result_check[0]
else: 
    last_id = 0
# ---------------------------------------------------------- 
print("Last ID:" + str(last_id), flush=True) 
# ---------------------------------------------------------- 


# ----------------------------------------------------------   
query = " Select "
query += " scriptx  "  
query += " , id  "  
query += " from jobstreet_raws_2023_07 "     
query += " where id > " + str(last_id)   
query += " order by id asc "     
# ----------------------------------------------------------  
# print(space + query, flush=True)
# ----------------------------------------------------------    
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
mycursor.execute(query)
myresult = mycursor.fetchall()
mycursor.close()
mydb.close()
# ----------------------------------------------------------
for x in myresult:    
    scriptx     = x[0] 
    idx         = x[1] 

    pre_scriptx = scriptx.split('"companyWebsite":"') 
    pre_scriptx2 = pre_scriptx[1].split('"') 

    text = pre_scriptx2[0]
    # ------------------------------------------------------ 
    print(str(idx) + " __ " + text, flush=True) 
    # ------------------------------------------------------ 
 
    # ------------------------------------------------------  
    # ------------------------------------------------------ 
    query_commit = "INSERT INTO `"+entity+"`( "
    # ------------------------------------------------------ 
    query_commit += " `fk_id`, " 
    query_commit += " `name` " 
    query_commit += " ) VALUES ( "
    query_commit += " '" + str(idx) + "', "    
    query_commit += ' "' + str(text).replace("'", "\\'") + '" '
    query_commit += " )  " 
    # ------------------------------------------------------ 
    print(space + query_commit, flush=True)
    # ------------------------------------------------------  
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    mycursor.execute(query_commit)
    mydb.commit()     
    # ------------------------------------------------------ 
    mycursor.close()
    mydb.close()
    # ------------------------------------------------------
# Out:
# Last ID:32958
# 32959 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32959',  ""  )
# 32960 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32960',  ""  )
# 32961 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32961',  ""  )
# 32962 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32962',  ""  )
# 32963 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32963',  ""  )
# 32964 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32964',  ""  )
# 32965 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32965',  ""  )
# 32966 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32966',  ""  )
# 32967 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32967',  ""  )
# 32968 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32968',  ""  )
# 32969 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32969',  ""  )
# 32970 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32970',  ""  )
# 32971 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32971',  ""  )
# 32972 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32972',  ""  )
# 32973 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32973',  ""  )
# 32974 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32974',  ""  )
# 32975 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32975',  ""  )
# 32976 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32976',  ""  )
# 32977 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32977',  ""  )
# 32978 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32978',  ""  )
# 32979 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32979',  ""  )
# 32980 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32980',  ""  )
# 32981 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32981',  ""  )
# 32982 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32982',  ""  )
# 32983 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32983',  ""  )
# 32984 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '32984',  ""  )
# 32985 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '
__
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33465',  ""  )
# 33466 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33466',  ""  )
# 33467 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33467',  ""  )
# 33468 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33468',  ""  )
# 33469 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33469',  ""  )
# 33470 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33470',  ""  )
# 33471 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33471',  ""  )
# 33472 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33472',  ""  )
# 33473 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33473',  ""  )
# 33474 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33474',  ""  )
# 33475 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33475',  ""  )
# 33476 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33476',  ""  )
# 33477 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33477',  ""  )
# 33478 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33478',  ""  )
# 33479 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '33479',  ""  )
# 33480 __
# ...
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48500',  ""  )
# 48501 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48501',  ""  )
# 48502 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48502',  ""  )
# 48503 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48503',  ""  )
# 48504 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48504',  ""  )
# 48505 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48505',  ""  )
# 48506 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48506',  ""  )
# 48507 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48507',  ""  )
# 48508 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48508',  ""  )
# 48509 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48509',  ""  )
# 48510 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48510',  ""  )
# 48511 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48511',  ""  )
# 48512 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48512',  ""  )
# 48513 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48513',  ""  )
# 48514 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48514',  ""  )
# 48515 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48515',  ""  )
# 48516 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48516',  ""  )
# 48517 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48517',  ""  )
# 48518 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48518',  ""  )
# 48519 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48519',  ""  )
# 48520 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48520',  ""  )
# 48521 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48521',  ""  )
# 48522 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48522',  ""  )
# 48523 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48523',  ""  )
# 48524 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48524',  ""  )
# 48525 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48525',  ""  )
# 48526 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48526',  ""  )
# 48527 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48527',  ""  )
# 48528 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48528',  ""  )
# 48529 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48529',  ""  )
# 48530 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48530',  ""  )
# 48531 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48531',  ""  )
# 48532 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48532',  ""  )
# 48533 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48533',  ""  )
# 48534 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48534',  ""  )
# 48535 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48535',  ""  )
# 48536 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48536',  ""  )
# 48537 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48537',  ""  )
# 48538 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48538',  ""  )
# 48539 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48539',  ""  )
# 48540 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48540',  ""  )
# 48541 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48541',  ""  )
# 48542 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48542',  ""  )
# 48543 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48543',  ""  )
# 48544 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48544',  ""  )
# 48545 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48545',  ""  )
# 48546 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48546',  ""  )
# 48547 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48547',  ""  )
# 48548 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48548',  ""  )
# 48549 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48549',  ""  )
# 48550 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48550',  ""  )
# 48551 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48551',  ""  )
# 48552 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48552',  ""  )
# 48553 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48553',  ""  )
# 48554 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48554',  ""  )
# 48555 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48555',  ""  )
# 48556 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48556',  ""  )
# 48557 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48557',  ""  )
# 48558 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48558',  ""  )
# 48559 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48559',  ""  )
# 48560 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48560',  ""  )
# 48561 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48561',  ""  )
# 48562 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48562',  ""  )
# 48563 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48563',  ""  )
# 48564 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48564',  ""  )
# 48565 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48565',  ""  )
# 48566 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48566',  ""  )
# 48567 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48567',  ""  )
# 48568 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48568',  ""  )
# 48569 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48569',  ""  )
# 48570 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48570',  ""  )
# 48571 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48571',  ""  )
# 48572 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48572',  ""  )
# 48573 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48573',  ""  )
# 48574 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48574',  ""  )
# 48575 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48575',  ""  )
# 48576 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48576',  ""  )
# 48577 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48577',  ""  )
# 48578 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48578',  ""  )
# 48579 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48579',  ""  )
# 48580 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48580',  ""  )
# 48581 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48581',  ""  )
# 48582 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48582',  ""  )
# 48583 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48583',  ""  )
# 48584 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48584',  ""  )
# 48585 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48585',  ""  )
# 48586 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48586',  ""  )
# 48587 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48587',  ""  )
# 48588 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48588',  ""  )
# 48589 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48589',  ""  )
# 48590 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48590',  ""  )
# 48591 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48591',  ""  )
# 48592 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48592',  ""  )
# 48593 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48593',  ""  )
# 48594 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48594',  ""  )
# 48595 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48595',  ""  )
# 48596 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48596',  ""  )
# 48597 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48597',  ""  )
# 48598 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48598',  ""  )
# 48599 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48599',  ""  )
# 48600 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48600',  ""  )
# 48601 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48601',  ""  )
# 48602 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48602',  ""  )
# 48603 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48603',  ""  )
# 48604 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48604',  ""  )
# 48605 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48605',  ""  )
# 48606 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48606',  ""  )
# 48607 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48607',  ""  )
# 48608 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48608',  ""  )
# 48609 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48609',  ""  )
# 48610 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48610',  ""  )
# 48611 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48611',  ""  )
# 48612 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48612',  ""  )
# 48613 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48613',  ""  )
# 48614 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48614',  ""  )
# 48615 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48615',  ""  )
# 48616 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48616',  ""  )
# 48617 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48617',  ""  )
# 48618 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48618',  ""  )
# 48619 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48619',  ""  )
# 48620 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48620',  ""  )
# 48621 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48621',  ""  )
# 48622 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48622',  ""  )
# 48623 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48623',  ""  )
# 48624 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48624',  ""  )
# 48625 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48625',  ""  )
# 48626 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48626',  ""  )
# 48627 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48627',  ""  )
# 48628 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48628',  ""  )
# 48629 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48629',  ""  )
# 48630 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48630',  ""  )
# 48631 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48631',  ""  )
# 48632 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48632',  ""  )
# 48633 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48633',  ""  )
# 48634 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48634',  ""  )
# 48635 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48635',  ""  )
# 48636 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48636',  ""  )
# 48637 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48637',  ""  )
# 48638 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48638',  ""  )
# 48639 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48639',  ""  )
# 48640 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48640',  ""  )
# 48641 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48641',  ""  )
# 48642 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48642',  ""  )
# 48643 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48643',  ""  )
# 48644 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48644',  ""  )
# 48645 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48645',  ""  )
# 48646 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48646',  ""  )
# 48647 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48647',  ""  )
# 48648 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48648',  ""  )
# 48649 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48649',  ""  )
# 48650 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48650',  ""  )
# 48651 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48651',  ""  )
# 48652 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48652',  ""  )
# 48653 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48653',  ""  )
# 48654 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48654',  ""  )
# 48655 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48655',  ""  )
# 48656 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48656',  ""  )
# 48657 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48657',  ""  )
# 48658 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48658',  ""  )
# 48659 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48659',  ""  )
# 48660 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48660',  ""  )
# 48661 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48661',  ""  )
# 48662 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48662',  ""  )
# 48663 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48663',  ""  )
# 48664 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48664',  ""  )
# 48665 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48665',  ""  )
# 48666 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48666',  ""  )
# 48667 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48667',  ""  )
# 48668 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48668',  ""  )
# 48669 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48669',  ""  )
# 48670 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48670',  ""  )
# 48671 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48671',  ""  )
# 48672 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48672',  ""  )
# 48673 __
# __INSERT INTO `company_website`(  `fk_id`,  `name`  ) VALUES (  '48673',  ""  )
