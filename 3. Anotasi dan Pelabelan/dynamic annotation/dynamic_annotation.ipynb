# %%
# Import
import sys
sys.path.append('../../')
 
from a_models.annotation_laravel import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------   
    entity      = "jobdescription"  
    update      = "yes"  
    printx      = "no"  
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    dynamic_wildcard(entity, update, printx, space)
    # --------------------------------------------------   
    print(space + "End") 
    ####################################################
# Out:
#   ____dynamic_wildcard()
#   ______Select  id  , nama  , label  from anotasis  where done is null  and label is not null
#   ________Total Row(s) : 18
#   __________[1/18]  #762 __ Visio __ B-Kemampuan_teknis
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Visio%"  and done is null
#   ______________Total Row(s) : 1994
#   ______________ner length: 1
#   ______________label length: 1
#   __________[2/18]  #763 __ AutoCAD __ B-Kemampuan_teknis
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%AutoCAD%"  and done is null
#   ______________Total Row(s) : 1032
#   ______________ner length: 1
#   ______________label length: 1
#   __________[3/18]  #764 __ Melakukan live streaming __ B-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Melakukan live streaming%"  and done is null
#   ______________Total Row(s) : 70
#   ______________ner length: 3
#   ______________label length: 3
#   __________[4/18]  #765 __ Membuat konten video untuk instagram dan TikTok __ B-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Membuat konten video untuk instagram dan TikTok%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 7
#   ______________label length: 7
#   __________[5/18]  #766 __ Membuat video wawancara dengan KOL __ B-Tugas I-Tugas I-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Membuat video wawancara dengan KOL%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 5
#   ______________label length: 5
#   __________[6/18]  #767 __ Meningkatkan brand awareness __ B-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Meningkatkan brand awareness%"  and done is null
#   ______________Total Row(s) : 37
#   ______________ner length: 3
#   ______________label length: 3
#   __________[7/18]  #768 __ Bertanggung jawab menciptakan , memonitor dan mengembangkan konten sosial instagram dan TikTok __ B-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Bertanggung jawab menciptakan , memonitor dan mengembangkan konten sosial instagram dan TikTok%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 12
#   ______________label length: 12
#   __________[8/18]  #769 __ Kab . Kepulauan Selayar __ B-Penempatan_kota I-Penempatan_kota I-Penempatan_kota I-Penempatan_kota
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Kab . Kepulauan Selayar%"  and done is null
#   ______________Total Row(s) : 0
#   ______________ner length: 4
#   ______________label length: 4
#   __________[9/18]  #770 __ Notion __ B-Kemampuan_teknis
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Notion%"  and done is null
#   ______________Total Row(s) : 57
#   ______________ner length: 1
#   ______________label length: 1
#   __________[10/18]  #771 __ GSlides __ B-Kemampuan_teknis
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%GSlides%"  and done is null
#   ______________Total Row(s) : 52
#   ______________ner length: 1
#   ______________label length: 1
#   __________[11/18]  #772 __ Gsheet __ B-Kemampuan_teknis
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Gsheet%"  and done is null
#   ______________Total Row(s) : 68
#   ______________ner length: 1
#   ______________label length: 1
#   __________[12/18]  #773 __ GForm __ B-Kemampuan_teknis
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%GForm%"  and done is null
#   ______________Total Row(s) : 49
#   ______________ner length: 1
#   ______________label length: 1
#   __________[13/18]  #774 __ Sertifikat associate program __ B-Tunjangan I-Tunjangan I-Tunjangan
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Sertifikat associate program%"  and done is null
#   ______________Total Row(s) : 45
#   ______________ner length: 3
#   ______________label length: 3
#   __________[14/18]  #775 __ Assess product __ B-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Assess product%"  and done is null
#   ______________Total Row(s) : 3
#   ______________ner length: 2
#   ______________label length: 2
#   __________[15/18]  #776 __ process changes and projects __ B-Tugas I-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%process changes and projects%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 4
#   ______________label length: 4
#   __________[16/18]  #777 __ Coordinate Global Regulatory Assessment of changes __ B-Tugas I-Tugas I-Tugas I-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Coordinate Global Regulatory Assessment of changes%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 6
#   ______________label length: 6
#   __________[17/18]  #778 __ Support and prepare Regulatory Submissions __ B-Tugas I-Tugas I-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Support and prepare Regulatory Submissions%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 5
#   ______________label length: 5
#   __________[18/18]  #779 __ Coordinate Global Registration __ B-Tugas I-Tugas I-Tugas
#   __________wildcard()
#   ____________Select  id  , dataset  , label  from jobdescription where dataset like "%Coordinate Global Registration%"  and done is null
#   ______________Total Row(s) : 2
#   ______________ner length: 3
#   ______________label length: 3
#   __End
