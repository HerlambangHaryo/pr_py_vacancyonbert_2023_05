# %%
# Import
import sys
sys.path.append('../../../')
 
from a_models.annotation import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity      = "jobdescription"  
    ner         = "Perempuan"  
    label       = "B-Jenis_kelamin"  
    entitas     = "jenis_kelamin"  
    update      = "yes"  
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    wildcard(entity, ner, label, entitas, update, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____wildcard()
#   ______Select  id  , name  , label  from jobdescription where name like '%Perempuan%'
#   ________Total Row(s) : 94
#   ________ner length: 1
#   ________label length: 1
#   __________[1/94]  Laki - laki / Perempuan usia max 32 tahun
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O O O B-Jenis_kelamin O O O O
#   ____________________  O O O O B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan usia max 32 tahun',  `label`='O O O O B-Jenis_kelamin O O O O',  `space_length`='9',  `jenis_kelamin` = 1  WHERE id = '76286'
#   ________
#   __________[2/94]  - Laki - laki / Perempuan usia max 45 th
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O
#   ____________________  O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Laki - laki / Perempuan usia max 45 th',  `label`='O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O',  `space_length`='10',  `jenis_kelamin` = 1  WHERE id = '191664'
#   ________
#   __________[3/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '217647'
#   ________
#   __________[4/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '243836'
#   ________
#   __________[5/94]  - Laki - laki / Perempuan
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O B-Jenis_kelamin
#   ____________________  O O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Laki - laki / Perempuan',  `label`='O O O O O B-Jenis_kelamin',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '249790'
#   ________
#   __________[6/94]  laki - laki dan perempuan .
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O O
#   ____________________  O O O O B-Jenis_kelamin O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='laki - laki dan perempuan .',  `label`='O O O O B-Jenis_kelamin O',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '253076'
#   ________
#   __________[7/94]  - Laki - laki / Perempuan
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O B-Jenis_kelamin
#   ____________________  O O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Laki - laki / Perempuan',  `label`='O O O O O B-Jenis_kelamin',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '257590'
#   ________
#   __________[8/94]  Laki / Perempuan
#   ____________________  Old len: 3 __ New len: 3
#   ____________________  O O B-Jenis_kelamin
#   ____________________  O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki / Perempuan',  `label`='O O B-Jenis_kelamin',  `space_length`='3',  `jenis_kelamin` = 1  WHERE id = '262787'
#   ________
#   __________[9/94]  - Laki - laki / Perempuan
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O B-Jenis_kelamin
#   ____________________  O O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Laki - laki / Perempuan',  `label`='O O O O O B-Jenis_kelamin',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '293109'
#   ________
#   __________[10/94]  laki atau perempuan
#   ____________________  Old len: 3 __ New len: 3
#   ____________________  O O O
#   ____________________  O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='laki atau perempuan',  `label`='O O B-Jenis_kelamin',  `space_length`='3',  `jenis_kelamin` = 1  WHERE id = '367348'
#   ________
#   __________[11/94]  - laki - laki dan perempuan - usia maksimal 26 tahun - pendidikan min SMA / SMK - memiliki pengalaman di bidang yang sama - mampu bekerja di bawah tekanan - mampu berkomunikasi dengan baik - Berpenampilan rapi
#   ____________________  Old len: 38 __ New len: 38
#   ____________________  O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O B-Jenis_kelamin O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- laki - laki dan perempuan - usia maksimal 26 tahun - pendidikan min SMA / SMK - memiliki pengalaman di bidang yang sama - mampu bekerja di bawah tekanan - mampu berkomunikasi dengan baik - Berpenampilan rapi',  `label`='O O O O O B-Jenis_kelamin O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O',  `space_length`='38',  `jenis_kelamin` = 1  WHERE id = '600761'
#   ________
#   __________[12/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '630750'
#   ________
#   __________[13/94]  laki - laki dan perempuan .
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O O
#   ____________________  O O O O B-Jenis_kelamin O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='laki - laki dan perempuan .',  `label`='O O O O B-Jenis_kelamin O',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '637201'
#   ________
#   __________[14/94]  laki atau perempuan silahkan melamar .
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O O
#   ____________________  O O B-Jenis_kelamin O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='laki atau perempuan silahkan melamar .',  `label`='O O B-Jenis_kelamin O O O',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '662380'
#   ________
#   __________[15/94]  Laki - laki / Perempuan usia max 32 tahun
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O O O B-Jenis_kelamin O O O O
#   ____________________  O O O O B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan usia max 32 tahun',  `label`='O O O O B-Jenis_kelamin O O O O',  `space_length`='9',  `jenis_kelamin` = 1  WHERE id = '676274'
#   ________
#   __________[16/94]  Laki - laki / Perempuan usia maks .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O O O O B-Jenis_kelamin O O O
#   ____________________  O O O O B-Jenis_kelamin O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan usia maks .',  `label`='O O O O B-Jenis_kelamin O O O',  `space_length`='8',  `jenis_kelamin` = 1  WHERE id = '740310'
#   ________
#   __________[17/94]  Perempuan max usia 26 th Pendidikan min SMK / SMA Sederajat Disiplin dan Pekerja Keras Teliti , Jujur , dan Bertanggung Paham Microsoft Excel Jawab Memahami Social Media Mahir menggunakan aplikasi shopee Mahir mengedit Video Menguasai aplikasi CAPCUT Kreatif & Komunikatif
#   ____________________  Old len: 41 __ New len: 41
#   ____________________  B-Jenis_kelamin O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  B-Jenis_kelamin O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan max usia 26 th Pendidikan min SMK / SMA Sederajat Disiplin dan Pekerja Keras Teliti , Jujur , dan Bertanggung Paham Microsoft Excel Jawab Memahami Social Media Mahir menggunakan aplikasi shopee Mahir mengedit Video Menguasai aplikasi CAPCUT Kreatif & Komunikatif',  `label`='B-Jenis_kelamin O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='41',  `jenis_kelamin` = 1  WHERE id = '742583'
#   ________
#   __________[18/94]  Menganalisa tren untuk memastikan konten yang dibuat berkualitas Kualifikasi : - Perempuan - Pendidikan min SMA Sederajat - Usia max 27 tahun - Punya skil : Editing video Fotografi Videografi - Terbiasa membuat konten ( Tiktok , IG reels ) - Berani tampil depan kamera - Kreatif , komunikatif
#   ____________________  Old len: 49 __ New len: 49
#   ____________________  O O O O O O O O O O O B-Jenis_kelamin O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O B-Jenis_kelamin O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Menganalisa tren untuk memastikan konten yang dibuat berkualitas Kualifikasi : - Perempuan - Pendidikan min SMA Sederajat - Usia max 27 tahun - Punya skil : Editing video Fotografi Videografi - Terbiasa membuat konten ( Tiktok , IG reels ) - Berani tampil depan kamera - Kreatif , komunikatif',  `label`='O O O O O O O O O O O B-Jenis_kelamin O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='49',  `jenis_kelamin` = 1  WHERE id = '744393'
#   ________
#   __________[19/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '744427'
#   ________
#   __________[20/94]  Laki - laki atau Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki atau Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '745485'
#   ________
#   __________[21/94]  jenis kelamin / laki2 / perempuan ; laki dan perempuan 2 .
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O O O O O O O O O O O O
#   ____________________  O O O O O B-Jenis_kelamin O O O B-Jenis_kelamin O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='jenis kelamin / laki2 / perempuan ; laki dan perempuan 2 .',  `label`='O O O O O B-Jenis_kelamin O O O B-Jenis_kelamin O O',  `space_length`='12',  `jenis_kelamin` = 1  WHERE id = '746153'
#   ________
#   __________[22/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '747240'
#   ________
#   __________[23/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '747654'
#   ________
#   __________[24/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '748759'
#   ________
#   __________[25/94]  anak perempuan berusia 2 tahun .
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O O O O
#   ____________________  O B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='anak perempuan berusia 2 tahun .',  `label`='O B-Jenis_kelamin O O O O',  `space_length`='6',  `jenis_kelamin` = 1  WHERE id = '749581'
#   ________
#   __________[26/94]  Laki - laki / Perempuan 2 .
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O O O B-Jenis_kelamin O O
#   ____________________  O O O O B-Jenis_kelamin O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan 2 .',  `label`='O O O O B-Jenis_kelamin O O',  `space_length`='7',  `jenis_kelamin` = 1  WHERE id = '750605'
#   ________
#   __________[27/94]  - Bertanggung jawab terhadap stock produk - Membersihkan cafe dan menjaga kebersihan cafe - Menangani dan mengelola customer - Pria / Wanita - Tanpa Pengalaman Bekerja - SMA / SMK - 19 - 29 Tahun - Kandidat wajib upload foto - Terima kandidat dari mana saja Persyaratan Lainnya : - Laki - Laki / Perempuan maksimal usia 29 tahun - Memiliki pengalaman sebagai Server atau Waiter lebih disukai - Minimal SMA / SMK - Fresh graduate dipersilakan melamar - Sudah Vaksinasi Covid 19 Booster 1 - Periode kerja 12 Juli 2023 - 1 Agustus 2023 - Penempatan : Cafe Haagen - Dazs Tunjungan Plaza
#   ____________________  Old len: 102 __ New len: 104 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Bertanggung jawab terhadap stock produk - Membersihkan cafe dan menjaga kebersihan cafe - Menangani dan mengelola customer - Pria / Wanita - Tanpa Pengalaman Bekerja - SMA / SMK - 19 - 29 Tahun - Kandidat wajib upload foto - Terima kandidat dari mana saja Persyaratan Lainnya : - Laki - Laki / Perempuan maksimal usia 29 tahun - Memiliki pengalaman sebagai Server atau Waiter lebih disukai - Minimal SMA / SMK - Fresh graduate dipersilakan melamar - Sudah Vaksinasi Covid 19 Booster 1 - Periode kerja 12 Juli 2023 - 1 Agustus 2023 - Penempatan : Cafe Haagen - Dazs Tunjungan Plaza',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='104',  `jenis_kelamin` = 1  WHERE id = '751501'
#   ________
#   __________[28/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '752908'
#   ________
#   __________[29/94]  Perempuan / Laki - laki Umur Max .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  B-Jenis_kelamin O O O O O O O
#   ____________________  B-Jenis_kelamin O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan / Laki - laki Umur Max .',  `label`='B-Jenis_kelamin O O O O O O O',  `space_length`='8',  `jenis_kelamin` = 1  WHERE id = '757616'
#   ________
#   __________[30/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '757762'
#   ________
#   __________[31/94]  Jenis Kelamin Laki - Laki / Perempuan 4 .
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O O O O O B-Jenis_kelamin O O
#   ____________________  O O O O O O B-Jenis_kelamin O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Jenis Kelamin Laki - Laki / Perempuan 4 .',  `label`='O O O O O O B-Jenis_kelamin O O',  `space_length`='9',  `jenis_kelamin` = 1  WHERE id = '761311'
#   ________
#   __________[32/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '763325'
#   ________
#   __________[33/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '769376'
#   ________
#   __________[34/94]  Perempuan dan Good Looking
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  B-Jenis_kelamin O O O
#   ____________________  B-Jenis_kelamin O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan dan Good Looking',  `label`='B-Jenis_kelamin O O O',  `space_length`='4',  `jenis_kelamin` = 1  WHERE id = '773504'
#   ________
#   __________[35/94]  - Membuat daily content - Bertanggung jawab selama proses pembuatan konten ( proses perekaman , editing hingga tayang di media sosial ) - Memberikan report terhadap konten - konten yang dijalankan - Menganalisa tren untuk memastikan konten yang dibuat berkualitas Tidak sedang sekolah / kuliah atau kerja Laki - laki / Perempuan maks .
#   ____________________  Old len: 54 __ New len: 54
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Membuat daily content - Bertanggung jawab selama proses pembuatan konten ( proses perekaman , editing hingga tayang di media sosial ) - Memberikan report terhadap konten - konten yang dijalankan - Menganalisa tren untuk memastikan konten yang dibuat berkualitas Tidak sedang sekolah / kuliah atau kerja Laki - laki / Perempuan maks .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O',  `space_length`='54',  `jenis_kelamin` = 1  WHERE id = '775546'
#   ________
#   __________[36/94]  Jobdesk - Melakukan indentifikasi pasar dan tren konsumen terkait peluang untuk produk baru atau produk yang sedang diinginkan - Membuat ilustrasi dan mengkomunikasikan konsep desain terkait kompleksitas dari alur proses , build material , kerangka gambar , proses produksi , prototipe , dan Mock - up - Melakukan identifikasi terkait tekstur , bahan , finishing , dan printing - Mempertimbangkan kenyamanan dan kegunaan saat merancang produk baru - Memperbaiki dan mengembangkan desain produk yang sudah ada - Menggunakan perangkat lunak untuk mock - up 3D dalam rangka merancang produk dan komponennya - Mengumpulkan feedback terkait user experience Kualifikasi - Laki - laki / Perempuan - Pengalaman kerja sebelumnya sebagai Product Designer minimal 1 tahun - Sarjana Desain Produk atau bidang relevan serupa - Keterampilan komunikasi , presentasi , dan kepemimpinan yang luar biasa - Keterampilan organisasi dan manajemen waktu yang sangat baik - Keahlian analisa dan pemecahan masalah yang tajam - Kreatif dan Visioner - Menggunakan perangkat lunak pemodelan 3D untuk desain detail .
#   ____________________  Old len: 121 __ New len: 164 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Jobdesk - Melakukan indentifikasi pasar dan tren konsumen terkait peluang untuk produk baru atau produk yang sedang diinginkan - Membuat ilustrasi dan mengkomunikasikan konsep desain terkait kompleksitas dari alur proses , build material , kerangka gambar , proses produksi , prototipe , dan Mock - up - Melakukan identifikasi terkait tekstur , bahan , finishing , dan printing - Mempertimbangkan kenyamanan dan kegunaan saat merancang produk baru - Memperbaiki dan mengembangkan desain produk yang sudah ada - Menggunakan perangkat lunak untuk mock - up 3D dalam rangka merancang produk dan komponennya - Mengumpulkan feedback terkait user experience Kualifikasi - Laki - laki / Perempuan - Pengalaman kerja sebelumnya sebagai Product Designer minimal 1 tahun - Sarjana Desain Produk atau bidang relevan serupa - Keterampilan komunikasi , presentasi , dan kepemimpinan yang luar biasa - Keterampilan organisasi dan manajemen waktu yang sangat baik - Keahlian analisa dan pemecahan masalah yang tajam - Kreatif dan Visioner - Menggunakan perangkat lunak pemodelan 3D untuk desain detail .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='164',  `jenis_kelamin` = 1  WHERE id = '775860'
#   ________
#   __________[37/94]  - Membuat daily content - Bertanggung jawab selama proses pembuatan konten ( proses perekaman , editing hingga tayang di media sosial ) - Memberikan report terhadap konten - konten yang dijalankan - Menganalisa tren untuk memastikan konten yang dibuat berkualitas Tidak sedang sekolah / kuliah atau kerja Laki - laki / Perempuan maks .
#   ____________________  Old len: 54 __ New len: 54
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Membuat daily content - Bertanggung jawab selama proses pembuatan konten ( proses perekaman , editing hingga tayang di media sosial ) - Memberikan report terhadap konten - konten yang dijalankan - Menganalisa tren untuk memastikan konten yang dibuat berkualitas Tidak sedang sekolah / kuliah atau kerja Laki - laki / Perempuan maks .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O',  `space_length`='54',  `jenis_kelamin` = 1  WHERE id = '776540'
#   ________
#   __________[38/94]  ualifikasi : - Laki - laki dan Perempuan - Usia 20 - 28 tahun - Min .
#   ____________________  Old len: 17 __ New len: 17
#   ____________________  O O O O O O O B-Jenis_kelamin O O O O O O O O O
#   ____________________  O O O O O O O B-Jenis_kelamin O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='ualifikasi : - Laki - laki dan Perempuan - Usia 20 - 28 tahun - Min .',  `label`='O O O O O O O B-Jenis_kelamin O O O O O O O O O',  `space_length`='17',  `jenis_kelamin` = 1  WHERE id = '779157'
#   ________
#   __________[39/94]  Laki - Laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - Laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '779397'
#   ________
#   __________[40/94]  Perempuan , Usia Mak .
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  B-Jenis_kelamin O O O O
#   ____________________  B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan , Usia Mak .',  `label`='B-Jenis_kelamin O O O O',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '780470'
#   ________
#   __________[41/94]  Perempuan dan Good Looking
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  B-Jenis_kelamin O O O
#   ____________________  B-Jenis_kelamin O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan dan Good Looking',  `label`='B-Jenis_kelamin O O O',  `space_length`='4',  `jenis_kelamin` = 1  WHERE id = '780528'
#   ________
#   __________[42/94]  Kualifikasi : - Pendidikan , minimal SMA / SMK Sederajat - Laki - laki / Perempuan - Pengalaman minimal 1 tahun sebagai warehouse crew - Usia minimal 21 tahun - Memiliki attitude yang baik - Mempunyai skill komunikasi , teamwork yang baikdan memilki Motivasi tinggi , - Penempatan Taman Tekno , Tangerang Selatan - Dapat segera bergabung - Pria / Wanita - Berpengalaman 1 tahun - SMA / SMK - 21 - 30 Tahun - Terima kandidat tanpa foto diri - Kota sesuai penempatan kerja ( Kota Tangerang Selatan )
#   ____________________  Old len: 90 __ New len: 90
#   ____________________  O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Kualifikasi : - Pendidikan , minimal SMA / SMK Sederajat - Laki - laki / Perempuan - Pengalaman minimal 1 tahun sebagai warehouse crew - Usia minimal 21 tahun - Memiliki attitude yang baik - Mempunyai skill komunikasi , teamwork yang baikdan memilki Motivasi tinggi , - Penempatan Taman Tekno , Tangerang Selatan - Dapat segera bergabung - Pria / Wanita - Berpengalaman 1 tahun - SMA / SMK - 21 - 30 Tahun - Terima kandidat tanpa foto diri - Kota sesuai penempatan kerja ( Kota Tangerang Selatan )',  `label`='O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='90',  `jenis_kelamin` = 1  WHERE id = '780856'
#   ________
#   __________[43/94]  Perempuan atau Laki - laki
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  B-Jenis_kelamin O O O O
#   ____________________  B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan atau Laki - laki',  `label`='B-Jenis_kelamin O O O O',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '784155'
#   ________
#   __________[44/94]  - Mendampingi belajar siswa - Mendampingi kegiatan anak Persyaratan : - Perempuan / Laki - laki usia maksimal 27 th - Mahasiswa / Alumni PGSMP lebih diutamakan - Komunikatif , Sabar dan telaten - Menguasai materi SMP secara umum - Berpengalaman ngajar privat / sekolah - Bisa renang / olahraga lain ( poin plus ) - Pria / Wanita - Berpengalaman 1 tahun - S1 - 22 - 27 Tahun - Kandidat wajib upload foto - Terima kandidat dari mana saja
#   ____________________  Old len: 81 __ New len: 81
#   ____________________  O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Mendampingi belajar siswa - Mendampingi kegiatan anak Persyaratan : - Perempuan / Laki - laki usia maksimal 27 th - Mahasiswa / Alumni PGSMP lebih diutamakan - Komunikatif , Sabar dan telaten - Menguasai materi SMP secara umum - Berpengalaman ngajar privat / sekolah - Bisa renang / olahraga lain ( poin plus ) - Pria / Wanita - Berpengalaman 1 tahun - S1 - 22 - 27 Tahun - Kandidat wajib upload foto - Terima kandidat dari mana saja',  `label`='O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O',  `space_length`='81',  `jenis_kelamin` = 1  WHERE id = '784213'
#   ________
#   __________[45/94]  Perempuan atau Laki - laki
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  B-Jenis_kelamin O O O O
#   ____________________  B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan atau Laki - laki',  `label`='B-Jenis_kelamin O O O O',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '785476'
#   ________
#   __________[46/94]  - Memberikan informasi sesuai pertanyaan pelanggan dan memberikan sedukasi seputar produk yang dijual - Menjalin komunikasi yang baik dengan konsumen - Memproses dan mempersiapkan barang sesuai pemesanan - Merekap penjualan - Menghandle komplain Kualifikasi : - Perempuan - Usia max 18 tahun - Disiplin , jujur , Ramah , dan kerja keras - Mampu bekerjasama dengan team - Mampu mengelola medsos
#   ____________________  Old len: 61 __ New len: 61
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Memberikan informasi sesuai pertanyaan pelanggan dan memberikan sedukasi seputar produk yang dijual - Menjalin komunikasi yang baik dengan konsumen - Memproses dan mempersiapkan barang sesuai pemesanan - Merekap penjualan - Menghandle komplain Kualifikasi : - Perempuan - Usia max 18 tahun - Disiplin , jujur , Ramah , dan kerja keras - Mampu bekerjasama dengan team - Mampu mengelola medsos',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='61',  `jenis_kelamin` = 1  WHERE id = '793971'
#   ________
#   __________[47/94]  Laki - laki / Perempuan ( Maks .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O O O O B-Jenis_kelamin O O O
#   ____________________  O O O O B-Jenis_kelamin O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan ( Maks .',  `label`='O O O O B-Jenis_kelamin O O O',  `space_length`='8',  `jenis_kelamin` = 1  WHERE id = '794566'
#   ________
#   __________[48/94]  - Melakukan audit keuangan sebulan sekali - Membuat laporan terkait audit tersebut - Mengidentifiklasi seluruh keuangan yang masuk dan keluar dengan baik dan teliti - Laki - laki / perempuan max 30 tahun - Pendidikan min SMA / K - Menguasai Ms .
#   ____________________  Old len: 43 __ New len: 43
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Melakukan audit keuangan sebulan sekali - Membuat laporan terkait audit tersebut - Mengidentifiklasi seluruh keuangan yang masuk dan keluar dengan baik dan teliti - Laki - laki / perempuan max 30 tahun - Pendidikan min SMA / K - Menguasai Ms .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O B-Tingkat_pendidikan O O O O O',  `space_length`='43',  `jenis_kelamin` = 1  WHERE id = '794862'
#   ________
#   __________[49/94]  - Memberikan informasi sesuai pertanyaan pelanggan dan memberikan sedukasi seputar produk yang dijual - Menjalin komunikasi yang baik dengan konsumen - Memproses dan mempersiapkan barang sesuai pemesanan - Merekap penjualan - Menghandle komplain Kualifikasi : - Perempuan - Usia max 18 tahun - Disiplin , jujur , Ramah , dan kerja keras - Mampu bekerjasama dengan team - Mampu mengelola medsos
#   ____________________  Old len: 61 __ New len: 61
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Memberikan informasi sesuai pertanyaan pelanggan dan memberikan sedukasi seputar produk yang dijual - Menjalin komunikasi yang baik dengan konsumen - Memproses dan mempersiapkan barang sesuai pemesanan - Merekap penjualan - Menghandle komplain Kualifikasi : - Perempuan - Usia max 18 tahun - Disiplin , jujur , Ramah , dan kerja keras - Mampu bekerjasama dengan team - Mampu mengelola medsos',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='61',  `jenis_kelamin` = 1  WHERE id = '795162'
#   ________
#   __________[50/94]  - Menjaga kebersihan area outlet - Memastikan makanan terjamin kebersihan - Menulis pesanan pelanggan dan mengantarkan saat sudah siap - Laki - laki / perempuan - Min 1 tahun pengalaman di bidang yang sama - Good attitude dan pekerja keras - Fasih berbahasa Inggris - Dapat bekerja secara team - Min pendidikan SMK / SMA - Max usia 25 tahun
#   ____________________  Old len: 60 __ New len: 60
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Menjaga kebersihan area outlet - Memastikan makanan terjamin kebersihan - Menulis pesanan pelanggan dan mengantarkan saat sudah siap - Laki - laki / perempuan - Min 1 tahun pengalaman di bidang yang sama - Good attitude dan pekerja keras - Fasih berbahasa Inggris - Dapat bekerja secara team - Min pendidikan SMK / SMA - Max usia 25 tahun',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='60',  `jenis_kelamin` = 1  WHERE id = '799511'
#   ________
#   __________[51/94]  - Menjaga kebersihan area outlet - Memastikan makanan terjamin kebersihan - Menulis pesanan pelanggan dan mengantarkan saat sudah siap - Laki - laki / perempuan - Min 1 tahun pengalaman di bidang yang sama - Good attitude dan pekerja keras - Fasih berbahasa Inggris - Dapat bekerja secara team - Min pendidikan SMK / SMA - Max usia 25 tahun
#   ____________________  Old len: 60 __ New len: 60
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Menjaga kebersihan area outlet - Memastikan makanan terjamin kebersihan - Menulis pesanan pelanggan dan mengantarkan saat sudah siap - Laki - laki / perempuan - Min 1 tahun pengalaman di bidang yang sama - Good attitude dan pekerja keras - Fasih berbahasa Inggris - Dapat bekerja secara team - Min pendidikan SMK / SMA - Max usia 25 tahun',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='60',  `jenis_kelamin` = 1  WHERE id = '799851'
#   ________
#   __________[52/94]  Laki2 / Perempuan 2 .
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O B-Jenis_kelamin O O
#   ____________________  O O B-Jenis_kelamin O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki2 / Perempuan 2 .',  `label`='O O B-Jenis_kelamin O O',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '800005'
#   ________
#   __________[53/94]  - Berkontribusi pada pertumbuhan perusahaan Kualifikasi : - Laki - laki / Perempuan - Usia Max 38 tahun - Pendidikan min SMA / K - Memiliki pengalaman min1 tahun di bidang Multifinance
#   ____________________  Old len: 32 __ New len: 32
#   ____________________  O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O
#   ____________________  O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Berkontribusi pada pertumbuhan perusahaan Kualifikasi : - Laki - laki / Perempuan - Usia Max 38 tahun - Pendidikan min SMA / K - Memiliki pengalaman min1 tahun di bidang Multifinance',  `label`='O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O',  `space_length`='32',  `jenis_kelamin` = 1  WHERE id = '800028'
#   ________
#   __________[54/94]  Kualifikasi : - Lulusan min SMA / SMK Sederajat - Laki - laki / Perempuan - Usia min 19 tahun - Mampu bekerja dengan tim dan berorientasi dengan target - Memiliki kemampuan komunikasi dengan baik - Kreatif , produktif , dan solutif - Memiliki kendaraan bermotor
#   ____________________  Old len: 46 __ New len: 46
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Kualifikasi : - Lulusan min SMA / SMK Sederajat - Laki - laki / Perempuan - Usia min 19 tahun - Mampu bekerja dengan tim dan berorientasi dengan target - Memiliki kemampuan komunikasi dengan baik - Kreatif , produktif , dan solutif - Memiliki kendaraan bermotor',  `label`='O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='46',  `jenis_kelamin` = 1  WHERE id = '800799'
#   ________
#   __________[55/94]  - Memasarkan produk asuransi AIA kepada nasabah - Membangun dan membina hubungan baik dengan nasabah - Bertindak sebagai representatif AIA yang memberikan layanan kepada nasabah Laki - laki / Perempuan , Umur 23 - 50
#   ____________________  Old len: 35 __ New len: 35
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Memasarkan produk asuransi AIA kepada nasabah - Membangun dan membina hubungan baik dengan nasabah - Bertindak sebagai representatif AIA yang memberikan layanan kepada nasabah Laki - laki / Perempuan , Umur 23 - 50',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O',  `space_length`='35',  `jenis_kelamin` = 1  WHERE id = '801329'
#   ________
#   __________[56/94]  - Memasarkan produk asuransi AIA kepada nasabah - Membangun dan membina hubungan baik dengan nasabah - Bertindak sebagai representatif AIA yang memberikan layanan kepada nasabah Laki - laki / Perempuan , Umur 23 - 50
#   ____________________  Old len: 35 __ New len: 35
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Memasarkan produk asuransi AIA kepada nasabah - Membangun dan membina hubungan baik dengan nasabah - Bertindak sebagai representatif AIA yang memberikan layanan kepada nasabah Laki - laki / Perempuan , Umur 23 - 50',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O',  `space_length`='35',  `jenis_kelamin` = 1  WHERE id = '801446'
#   ________
#   __________[57/94]  - Menerima pembayaran dan pengembaalian uang konsumen - Melakukan cek uang - Mengelola uang masuk harian - Membuat laporan harian - Laki - laki / perempuan - Min 1 tahun pengalaman di bidang yang sama - Good attitude dan pekerja keras - Fasih berbahasa Inggris - Dapat bekerja secara team - Min pendidikan SMK / SMA - Max usia 25 tahun
#   ____________________  Old len: 61 __ New len: 61
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Menerima pembayaran dan pengembaalian uang konsumen - Melakukan cek uang - Mengelola uang masuk harian - Membuat laporan harian - Laki - laki / perempuan - Min 1 tahun pengalaman di bidang yang sama - Good attitude dan pekerja keras - Fasih berbahasa Inggris - Dapat bekerja secara team - Min pendidikan SMK / SMA - Max usia 25 tahun',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='61',  `jenis_kelamin` = 1  WHERE id = '801689'
#   ________
#   __________[58/94]  Kualifikasi : - Perempuan , single , usia maks 25th - Berpenampilan menarik - Bisa berkomunikasi dengan baik - Siap bekerja di tanggal merah - Dekat ke Lokasi / Punya kendaraan - Gaji 2 - 3 jt
#   ____________________  Old len: 37 __ New len: 37
#   ____________________  O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Kualifikasi : - Perempuan , single , usia maks 25th - Berpenampilan menarik - Bisa berkomunikasi dengan baik - Siap bekerja di tanggal merah - Dekat ke Lokasi / Punya kendaraan - Gaji 2 - 3 jt',  `label`='O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='37',  `jenis_kelamin` = 1  WHERE id = '802054'
#   ________
#   __________[59/94]  - perempuan , fresh graduate dipersilahkan melamar - pendidikan minimal sarjana ekonomi , akuntansi , statistik , dan lain - lain yang terkait dari universitas terkemuka - mampu mengoperasikan microsoft word dan excel - berintegritas tinggi dan memiliki karakter yang kuat untuk beradaptasi dengan lingkungan kerja , kepemimpinan yang kuat , manajemen , dan mampu bekerja individu maupun dalam tim - mamu berkomunikasi yang baik , berbahasa mandarin disukai - bersedia ditempatkan di gresik , jawa timur
#   ____________________  Old len: 77 __ New len: 77
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- perempuan , fresh graduate dipersilahkan melamar - pendidikan minimal sarjana ekonomi , akuntansi , statistik , dan lain - lain yang terkait dari universitas terkemuka - mampu mengoperasikan microsoft word dan excel - berintegritas tinggi dan memiliki karakter yang kuat untuk beradaptasi dengan lingkungan kerja , kepemimpinan yang kuat , manajemen , dan mampu bekerja individu maupun dalam tim - mamu berkomunikasi yang baik , berbahasa mandarin disukai - bersedia ditempatkan di gresik , jawa timur',  `label`='O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='77',  `jenis_kelamin` = 1  WHERE id = '802192'
#   ________
# ...
#   ____________________  Old len: 45 __ New len: 45
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='harga dll ) Event toko Pendidikan minimal SMA / SMK Laki - Laki / Perempuan Kreatif , dengan ide Out Of The Box Bisa software editing Grafis , Photo & Video Contoh : Corel Draw , Photoshop , Premier , Capcut Sertakan portofolio hasil karyamu',  `label`='O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='45',  `jenis_kelamin` = 1  WHERE id = '834611'
#   ________
#   __________[80/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '844214'
#   ________
#   __________[81/94]  Kualifikasi : - Pendidikan , minimal SMA / SMK Sederajat - Laki - laki / Perempuan - Pengalaman minimal 1 tahun sebagai warehouse crew - Usia minimal 21 tahun - Memiliki attitude yang baik - Mempunyai skill komunikasi , teamwork yang baikdan memilki Motivasi tinggi , - Penempatan Taman Tekno , Tangerang Selatan - Dapat segera bergabung - Pria / Wanita - Berpengalaman 1 tahun - SMA / SMK - 21 - 30 Tahun - Terima kandidat tanpa foto diri - Kota sesuai penempatan kerja ( Kota Tangerang Selatan )
#   ____________________  Old len: 90 __ New len: 90
#   ____________________  O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Kualifikasi : - Pendidikan , minimal SMA / SMK Sederajat - Laki - laki / Perempuan - Pengalaman minimal 1 tahun sebagai warehouse crew - Usia minimal 21 tahun - Memiliki attitude yang baik - Mempunyai skill komunikasi , teamwork yang baikdan memilki Motivasi tinggi , - Penempatan Taman Tekno , Tangerang Selatan - Dapat segera bergabung - Pria / Wanita - Berpengalaman 1 tahun - SMA / SMK - 21 - 30 Tahun - Terima kandidat tanpa foto diri - Kota sesuai penempatan kerja ( Kota Tangerang Selatan )',  `label`='O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='90',  `jenis_kelamin` = 1  WHERE id = '846565'
#   ________
#   __________[82/94]  Perempuan , Usia Mak .
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  B-Jenis_kelamin O O O O
#   ____________________  B-Jenis_kelamin O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan , Usia Mak .',  `label`='B-Jenis_kelamin O O O O',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '846935'
#   ________
#   __________[83/94]  ualifikasi : - Laki - laki dan Perempuan - Usia 20 - 28 tahun - Min .
#   ____________________  Old len: 17 __ New len: 17
#   ____________________  O O O O O O O B-Jenis_kelamin O O O O O O O O O
#   ____________________  O O O O O O O B-Jenis_kelamin O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='ualifikasi : - Laki - laki dan Perempuan - Usia 20 - 28 tahun - Min .',  `label`='O O O O O O O B-Jenis_kelamin O O O O O O O O O',  `space_length`='17',  `jenis_kelamin` = 1  WHERE id = '847967'
#   ________
#   __________[84/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '850742'
#   ________
#   __________[85/94]  Jobdesk - Melakukan indentifikasi pasar dan tren konsumen terkait peluang untuk produk baru atau produk yang sedang diinginkan - Membuat ilustrasi dan mengkomunikasikan konsep desain terkait kompleksitas dari alur proses , build material , kerangka gambar , proses produksi , prototipe , dan Mock - up - Melakukan identifikasi terkait tekstur , bahan , finishing , dan printing - Mempertimbangkan kenyamanan dan kegunaan saat merancang produk baru - Memperbaiki dan mengembangkan desain produk yang sudah ada - Menggunakan perangkat lunak untuk mock - up 3D dalam rangka merancang produk dan komponennya - Mengumpulkan feedback terkait user experience Kualifikasi - Laki - laki / Perempuan - Pengalaman kerja sebelumnya sebagai Product Designer minimal 1 tahun - Sarjana Desain Produk atau bidang relevan serupa - Keterampilan komunikasi , presentasi , dan kepemimpinan yang luar biasa - Keterampilan organisasi dan manajemen waktu yang sangat baik - Keahlian analisa dan pemecahan masalah yang tajam - Kreatif dan Visioner - Menggunakan perangkat lunak pemodelan 3D untuk desain detail .
#   ____________________  Old len: 121 __ New len: 164 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Jobdesk - Melakukan indentifikasi pasar dan tren konsumen terkait peluang untuk produk baru atau produk yang sedang diinginkan - Membuat ilustrasi dan mengkomunikasikan konsep desain terkait kompleksitas dari alur proses , build material , kerangka gambar , proses produksi , prototipe , dan Mock - up - Melakukan identifikasi terkait tekstur , bahan , finishing , dan printing - Mempertimbangkan kenyamanan dan kegunaan saat merancang produk baru - Memperbaiki dan mengembangkan desain produk yang sudah ada - Menggunakan perangkat lunak untuk mock - up 3D dalam rangka merancang produk dan komponennya - Mengumpulkan feedback terkait user experience Kualifikasi - Laki - laki / Perempuan - Pengalaman kerja sebelumnya sebagai Product Designer minimal 1 tahun - Sarjana Desain Produk atau bidang relevan serupa - Keterampilan komunikasi , presentasi , dan kepemimpinan yang luar biasa - Keterampilan organisasi dan manajemen waktu yang sangat baik - Keahlian analisa dan pemecahan masalah yang tajam - Kreatif dan Visioner - Menggunakan perangkat lunak pemodelan 3D untuk desain detail .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='164',  `jenis_kelamin` = 1  WHERE id = '851118'
#   ________
#   __________[86/94]  - Membuat daily content - Bertanggung jawab selama proses pembuatan konten ( proses perekaman , editing hingga tayang di media sosial ) - Memberikan report terhadap konten - konten yang dijalankan - Menganalisa tren untuk memastikan konten yang dibuat berkualitas Tidak sedang sekolah / kuliah atau kerja Laki - laki / Perempuan maks .
#   ____________________  Old len: 54 __ New len: 54
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Membuat daily content - Bertanggung jawab selama proses pembuatan konten ( proses perekaman , editing hingga tayang di media sosial ) - Memberikan report terhadap konten - konten yang dijalankan - Menganalisa tren untuk memastikan konten yang dibuat berkualitas Tidak sedang sekolah / kuliah atau kerja Laki - laki / Perempuan maks .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin B-Jenis_kelamin O',  `space_length`='54',  `jenis_kelamin` = 1  WHERE id = '851369'
#   ________
#   __________[87/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '852456'
#   ________
#   __________[88/94]  - Bertanggung jawab dalam memimpin dan bertanggung jawab terhadap seluruh proses kegiatan marketing agar target perusahaan tercapai - Menyusun , mengatur , menganalisis , mengimplementasi dan mengevaluasi manajemen pemasaran , penjualan dan promosi - Melakukan pengawasan dan pengendalian atas seluruh kinerja manajemen pemasaran , penjualan dan promosi - Lulusan / Mahasiswa D3 / S1 / S2 - Laki - laki / Perempuan - Usia 27 - 40 th - Tertarik entrepreneurship - Suka tantangan , kreatif dan bisa bekerja dalam tim
#   ____________________  Old len: 81 __ New len: 81
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Bertanggung jawab dalam memimpin dan bertanggung jawab terhadap seluruh proses kegiatan marketing agar target perusahaan tercapai - Menyusun , mengatur , menganalisis , mengimplementasi dan mengevaluasi manajemen pemasaran , penjualan dan promosi - Melakukan pengawasan dan pengendalian atas seluruh kinerja manajemen pemasaran , penjualan dan promosi - Lulusan / Mahasiswa D3 / S1 / S2 - Laki - laki / Perempuan - Usia 27 - 40 th - Tertarik entrepreneurship - Suka tantangan , kreatif dan bisa bekerja dalam tim',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O O O O O O',  `space_length`='81',  `jenis_kelamin` = 1  WHERE id = '852659'
#   ________
#   __________[89/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '852916'
#   ________
#   __________[90/94]  Laki - Laki / Perempuan , Maks 25 Tahun .
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O O O O B-Jenis_kelamin O O O O O
#   ____________________  O O O O B-Jenis_kelamin O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - Laki / Perempuan , Maks 25 Tahun .',  `label`='O O O O B-Jenis_kelamin O O O O O',  `space_length`='10',  `jenis_kelamin` = 1  WHERE id = '856552'
#   ________
#   __________[91/94]  Job Description : - Mendampingi belajar anak - Mendampingi kegiatan anak - Anak yang didampingi kelas 7 SMP ( 1 siswa ) Persyaratan : - Perempuan / Laki - laki usia maksimal 27 th - Mahasiswa / S1 Pendidikan ( lebih diutamakan ) - Komunikatif , Sabar dan telaten - Bisa mendampingi siswa mengerjakan Tugas Jam Kerja : 15 .
#   ____________________  Old len: 60 __ New len: 60
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Job Description : - Mendampingi belajar anak - Mendampingi kegiatan anak - Anak yang didampingi kelas 7 SMP ( 1 siswa ) Persyaratan : - Perempuan / Laki - laki usia maksimal 27 th - Mahasiswa / S1 Pendidikan ( lebih diutamakan ) - Komunikatif , Sabar dan telaten - Bisa mendampingi siswa mengerjakan Tugas Jam Kerja : 15 .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O B-Jenis_kelamin O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='60',  `jenis_kelamin` = 1  WHERE id = '858826'
#   ________
#   __________[92/94]  Laki - laki / Perempuan
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O O O B-Jenis_kelamin
#   ____________________  O O O O B-Jenis_kelamin
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Laki - laki / Perempuan',  `label`='O O O O B-Jenis_kelamin',  `space_length`='5',  `jenis_kelamin` = 1  WHERE id = '860747'
#   ________
#   __________[93/94]  Perempuan / Laki - laki 2 .
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  B-Jenis_kelamin O O O O O O
#   ____________________  B-Jenis_kelamin O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Perempuan / Laki - laki 2 .',  `label`='B-Jenis_kelamin O O O O O O',  `space_length`='7',  `jenis_kelamin` = 1  WHERE id = '861094'
#   ________
#   __________[94/94]  Kualifikasi : - Laki - laki / Perempuan beragama islam - Lulusan min S1 - Mampu berbicara inggris / arab secara aktif atau pasif
#   ____________________  Old len: 24 __ New len: 24
#   ____________________  O O O O O O O B-Jenis_kelamin O O O O O B-Tingkat_pendidikan O O O O O O O O O O
#   ____________________  O O O O O O O B-Jenis_kelamin O O O O O B-Tingkat_pendidikan O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Kualifikasi : - Laki - laki / Perempuan beragama islam - Lulusan min S1 - Mampu berbicara inggris / arab secara aktif atau pasif',  `label`='O O O O O O O B-Jenis_kelamin O O O O O B-Tingkat_pendidikan O O O O O O O O O O',  `space_length`='24',  `jenis_kelamin` = 1  WHERE id = '861769'
#   ________
