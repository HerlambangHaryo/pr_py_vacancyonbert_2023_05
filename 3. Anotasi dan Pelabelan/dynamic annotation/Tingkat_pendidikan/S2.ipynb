# %%
# Import
import sys
sys.path.append('../../')
 
from a_models.annotation import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity      = "jobdescription"  
    ner         = "S2"  
    label       = "B-Tingkat_pendidikan"  
    entitas     = "tingkat_pendidikan"  
    update      = "yes"  
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    wildcard(entity, ner, label, entitas, update, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____wildcard()
#   ______Select  id  , name  , label  from jobdescription where name like '%S2%'
#   ________Total Row(s) : 293
#   ________ner length: 1
#   ________label length: 1
#   __________[1/293]  minimal S1 Sarjana atau S2
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='minimal S1 Sarjana atau S2',  `label`='O B-Tingkat_pendidikan O O B-Tingkat_pendidikan',  `space_length`='5',  `tingkat_pendidikan` = 1  WHERE id = '831'
#   ________
#   __________[2/293]  CS2 Pola Sehat Pandaan , Jawa Timur
#   ____________________  Old len: 8 __ New len: 7 __ WARNING!
#   ____________________  O O O O O O O
#   ____________________  O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='CS2 Pola Sehat Pandaan , Jawa Timur',  `label`='O O O O O O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '8479'
#   ________
#   __________[3/293]  Minimal S1 / S2
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal S1 / S2',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '9346'
#   ________
#   __________[4/293]  Minimal tingkat pendidikan yang harus dimiliki kandidat ( contoh : SMA / Diploma / S1 / S2 ) STM / S1 teknik mesin
#   ____________________  Old len: 23 __ New len: 23
#   ____________________  O O O O O O O O O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O
#   ____________________  O O O O O O O O O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal tingkat pendidikan yang harus dimiliki kandidat ( contoh : SMA / Diploma / S1 / S2 ) STM / S1 teknik mesin',  `label`='O O O O O O O O O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O',  `space_length`='23',  `tingkat_pendidikan` = 1  WHERE id = '11425'
#   ________
#   __________[5/293]  Pendidikan S2 Kimia / Teknik Kimia
#   ____________________  Old len: 7 __ New len: 6 __ WARNING!
#   ____________________  O B-Tingkat_pendidikan O O O O
#   ____________________  O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S2 Kimia / Teknik Kimia',  `label`='O B-Tingkat_pendidikan O O O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '11731'
#   ________
#   __________[6/293]  Pendidikan minimal S1 / S2 semua jurusan
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S1 / S2 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '13597'
#   ________
#   __________[7/293]  - S1 / S2 dari jurusan Teknik Informatika , IT , atau jurusan terkait lain adalah nilai plus .
#   ____________________  Old len: 19 __ New len: 19
#   ____________________  O B-Tingkat_pendidikan B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- S1 / S2 dari jurusan Teknik Informatika , IT , atau jurusan terkait lain adalah nilai plus .',  `label`='O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O',  `space_length`='19',  `tingkat_pendidikan` = 1  WHERE id = '14396'
#   ________
#   __________[8/293]  atau S2 Masters Degree / Post Graduate in Mass Communication , Public Relations , Management .
#   ____________________  Old len: 18 __ New len: 16 __ WARNING!
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='atau S2 Masters Degree / Post Graduate in Mass Communication , Public Relations , Management .',  `label`='O B-Tingkat_pendidikan O O O O O O O O O O O O O O',  `space_length`='16',  `tingkat_pendidikan` = 1  WHERE id = '14961'
#   ________
#   __________[9/293]  beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 30 __ New len: 30
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='30',  `tingkat_pendidikan` = 1  WHERE id = '16731'
#   ________
#   __________[10/293]  At least S2 in any program
#   ____________________  Old len: 8 __ New len: 6 __ WARNING!
#   ____________________  O O O B-Tingkat_pendidikan O O O
#   ____________________  O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='At least S2 in any program',  `label`='O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '17844'
#   ________
#   __________[11/293]  PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 33 __ New len: 33
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='33',  `tingkat_pendidikan` = 1  WHERE id = '21638'
#   ________
#   __________[12/293]  Maksimal usia 25 tahun ( S1 ) / 26 tahun ( S2 ) .
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O
#   ____________________  O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Maksimal usia 25 tahun ( S1 ) / 26 tahun ( S2 ) .',  `label`='O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '22522'
#   ________
#   __________[13/293]  Minimum formal education : S1 , S2are welcome
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O O O O B-Tingkat_pendidikan O O O
#   ____________________  O O O O B-Tingkat_pendidikan O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimum formal education : S1 , S2are welcome',  `label`='O O O O B-Tingkat_pendidikan O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '24154'
#   ________
#   __________[14/293]  beberapa orang minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Elektro / Teknik Telekomunikasi / Sistem Informasi / Fisika / Matematika / Statistika / Ilmu Komputer / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 41 __ New len: 41
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Elektro / Teknik Telekomunikasi / Sistem Informasi / Fisika / Matematika / Statistika / Ilmu Komputer / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='41',  `tingkat_pendidikan` = 1  WHERE id = '25713'
#   ________
#   __________[15/293]  Diploma Pascasarjana / Magister ( S2 )
#   ____________________  Old len: 9 __ New len: 7 __ WARNING!
#   ____________________  O O O O O B-Tingkat_pendidikan O O
#   ____________________  O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Diploma Pascasarjana / Magister ( S2 )',  `label`='O O O O O B-Tingkat_pendidikan O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '26123'
#   ________
#   __________[16/293]  Lulusan DIII , S1 , S2
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan DIII , S1 , S2',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '26822'
#   ________
#   __________[17/293]  Pendidikan S1 / S2 segala jurusan
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / S2 segala jurusan',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '27516'
#   ________
#   __________[18/293]  S1 / S2 with minimum 3 - 5 years experience in Project Manager / Project Management or related position in creative agency field .
#   ____________________  Old len: 24 __ New len: 24
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 with minimum 3 - 5 years experience in Project Manager / Project Management or related position in creative agency field .',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='24',  `tingkat_pendidikan` = 1  WHERE id = '28003'
#   ________
#   __________[19/293]  - Berusia maksimal 35 tahun untuk lulusan S2 , dan 40 tahun untuk lulusan S3
#   ____________________  Old len: 17 __ New len: 15 __ WARNING!
#   ____________________  O O O O O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan
#   ____________________  O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Berusia maksimal 35 tahun untuk lulusan S2 , dan 40 tahun untuk lulusan S3',  `label`='O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '33426'
#   ________
#   __________[20/293]  Master ( S2 ) ≥ 3 , 0 c .
#   ____________________  Old len: 12 __ New len: 10 __ WARNING!
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Master ( S2 ) ≥ 3 , 0 c .',  `label`='O O B-Tingkat_pendidikan O O O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '33430'
#   ________
#   __________[21/293]  Peluang untuk mendapat beasiswa lanjut studiS2 atau S3
#   ____________________  Old len: 9 __ New len: 8 __ WARNING!
#   ____________________  O O O O O O O B-Tingkat_pendidikan
#   ____________________  O O O O O O O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Peluang untuk mendapat beasiswa lanjut studiS2 atau S3',  `label`='O O O O O O O B-Tingkat_pendidikan',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '34702'
#   ________
#   __________[22/293]  Pendidikan S1 / S2
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / S2',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '37221'
#   ________
#   __________[23/293]  Maksimal usia 25 tahun ( S1 ) / 26 tahun ( S2 )
#   ____________________  Old len: 13 __ New len: 13
#   ____________________  O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O
#   ____________________  O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Maksimal usia 25 tahun ( S1 ) / 26 tahun ( S2 )',  `label`='O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O',  `space_length`='13',  `tingkat_pendidikan` = 1  WHERE id = '38877'
#   ________
#   __________[24/293]  Minimal S2 , linier S1 dan S2dari Ilmu Komunikasi ( Jurnalistik / Broadcasting ) .
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal S2 , linier S1 dan S2dari Ilmu Komunikasi ( Jurnalistik / Broadcasting ) .',  `label`='O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O O O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '47746'
#   ________
#   __________[25/293]  Berpendidikkan minimal S2dari Perguruan Tinggi terkemuka dari dalam negeri dan / atau luar negeri .
#   ____________________  Old len: 17 __ New len: 15 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Berpendidikkan minimal S2dari Perguruan Tinggi terkemuka dari dalam negeri dan / atau luar negeri .',  `label`='O O O O O O O O O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '52696'
#   ________
#   __________[26/293]  - Membuat report harian setiap pagi untuk divisi T2 T0 , S1 S2 S3
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan
#   ____________________  O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Membuat report harian setiap pagi untuk divisi T2 T0 , S1 S2 S3',  `label`='O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '57707'
#   ________
#   __________[27/293]  S1 graduate from reputable university , preferably S2 graduate with major inTelecommunication , Technology , Computer andother field sciencesDeep knowledge on Sales preferably with some experience in telecommunication technologyStrongknowledge on SMS businessExcellent Oral and Written communication skills
#   ____________________  Old len: 37 __ New len: 37
#   ____________________  B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 graduate from reputable university , preferably S2 graduate with major inTelecommunication , Technology , Computer andother field sciencesDeep knowledge on Sales preferably with some experience in telecommunication technologyStrongknowledge on SMS businessExcellent Oral and Written communication skills',  `label`='B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='37',  `tingkat_pendidikan` = 1  WHERE id = '59953'
#   ________
#   __________[28/293]  beberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 29 __ New len: 29
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='29',  `tingkat_pendidikan` = 1  WHERE id = '64623'
#   ________
#   __________[29/293]  S1 / S2 Engineering Degree or trade with post graduate qualifications in Asset Management .
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 Engineering Degree or trade with post graduate qualifications in Asset Management .',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '68364'
#   ________
#   __________[30/293]  Pendidikan minimal S1 jurusan - Akuntansi dan S2 Finance lebih diutamakan
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S1 jurusan - Akuntansi dan S2 Finance lebih diutamakan',  `label`='O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '74452'
#   ________
#   __________[31/293]  Pendidikan S1 / S2 / S3
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / S2 / S3',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '87054'
#   ________
#   __________[32/293]  Pendidikan minimal S2
#   ____________________  Old len: 4 __ New len: 3 __ WARNING!
#   ____________________  O O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S2',  `label`='O O B-Tingkat_pendidikan',  `space_length`='3',  `tingkat_pendidikan` = 1  WHERE id = '88302'
#   ________
#   __________[33/293]  S1 / S2 ( Sistem Informasi / Manajemen Informasi / Teknik Informatika / Teknologi Informasi / sejenis )
#   ____________________  Old len: 18 __ New len: 18
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 ( Sistem Informasi / Manajemen Informasi / Teknik Informatika / Teknologi Informasi / sejenis )',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O',  `space_length`='18',  `tingkat_pendidikan` = 1  WHERE id = '89099'
#   ________
#   __________[34/293]  S1 / S2 jurusan Teknologi Pangan
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 jurusan Teknologi Pangan',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '91030'
#   ________
#   __________[35/293]  S2 - Freshgraduate are welcome ( postgraduate degree )
#   ____________________  Old len: 11 __ New len: 9 __ WARNING!
#   ____________________  B-Tingkat_pendidikan O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S2 - Freshgraduate are welcome ( postgraduate degree )',  `label`='B-Tingkat_pendidikan O O O O O O O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '99422'
#   ________
#   __________[36/293]  Pendidikan S1 Hukum , S2 akan diutamakan
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 Hukum , S2 akan diutamakan',  `label`='O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '104062'
#   ________
#   __________[37/293]  Pendidikan minimal S1 / S2 .
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S1 / S2 .',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '104202'
#   ________
#   __________[38/293]  Mengerti tentang Valves2 , baik Valves PVC , CS , Kuningan dan Stainless
#   ____________________  Old len: 14 __ New len: 13 __ WARNING!
#   ____________________  O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Mengerti tentang Valves2 , baik Valves PVC , CS , Kuningan dan Stainless',  `label`='O O O O O O O O O O O O O',  `space_length`='13',  `tingkat_pendidikan` = 1  WHERE id = '104581'
#   ________
#   __________[39/293]  Minimal S1 Teknik Mesin dan S2 Teknik Industri ( Konsentrasi Keahlian Manufaktur )
#   ____________________  Old len: 13 __ New len: 13
#   ____________________  O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal S1 Teknik Mesin dan S2 Teknik Industri ( Konsentrasi Keahlian Manufaktur )',  `label`='O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O',  `space_length`='13',  `tingkat_pendidikan` = 1  WHERE id = '106189'
#   ________
#   __________[40/293]  S2 Akuntansi
#   ____________________  Old len: 3 __ New len: 2 __ WARNING!
#   ____________________  B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S2 Akuntansi',  `label`='B-Tingkat_pendidikan O',  `space_length`='2',  `tingkat_pendidikan` = 1  WHERE id = '106455'
#   ________
#   __________[41/293]  Pendidikan S1 / S2 Hukum
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / S2 Hukum',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='5',  `tingkat_pendidikan` = 1  WHERE id = '107000'
#   ________
#   __________[42/293]  minimal S1 Sarjana atau S2
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='minimal S1 Sarjana atau S2',  `label`='O B-Tingkat_pendidikan O O B-Tingkat_pendidikan',  `space_length`='5',  `tingkat_pendidikan` = 1  WHERE id = '108761'
#   ________
#   __________[43/293]  Pendidikan S1 / S2
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / S2',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '115535'
#   ________
#   __________[44/293]  Pendidikan Minimal S1 / S2 Semua Jurusan
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan Minimal S1 / S2 Semua Jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '116345'
#   ________
#   __________[45/293]  Minimal S1 / S2
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal S1 / S2',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '117173'
#   ________
#   __________[46/293]  CS2 Pola Sehat Pandaan , Jawa Timur
#   ____________________  Old len: 8 __ New len: 7 __ WARNING!
#   ____________________  O O O O O O O
#   ____________________  O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='CS2 Pola Sehat Pandaan , Jawa Timur',  `label`='O O O O O O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '119087'
#   ________
#   __________[47/293]  Bachelor Degree ( S1 ) / Master Degree ( S2 ) in accounting / finance field , preferably with CPA ( Certified Public Accountant ) accreditation
#   ____________________  Old len: 26 __ New len: 26
#   ____________________  O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Bachelor Degree ( S1 ) / Master Degree ( S2 ) in accounting / finance field , preferably with CPA ( Certified Public Accountant ) accreditation',  `label`='O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O',  `space_length`='26',  `tingkat_pendidikan` = 1  WHERE id = '127772'
#   ________
#   __________[48/293]  Pendidikan S2 Kimia
#   ____________________  Old len: 4 __ New len: 3 __ WARNING!
#   ____________________  O B-Tingkat_pendidikan O
#   ____________________  O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S2 Kimia',  `label`='O B-Tingkat_pendidikan O',  `space_length`='3',  `tingkat_pendidikan` = 1  WHERE id = '128507'
#   ________
#   __________[49/293]  Pendidikan minimal S1 / S2 semua jurusan
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S1 / S2 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '130541'
#   ________
#   __________[50/293]  - S1 / S2 dari jurusan Teknik Informatika , IT , atau jurusan terkait lain adalah nilai plus .
#   ____________________  Old len: 19 __ New len: 19
#   ____________________  O B-Tingkat_pendidikan B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- S1 / S2 dari jurusan Teknik Informatika , IT , atau jurusan terkait lain adalah nilai plus .',  `label`='O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O',  `space_length`='19',  `tingkat_pendidikan` = 1  WHERE id = '131274'
#   ________
#   __________[51/293]  beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 30 __ New len: 30
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='30',  `tingkat_pendidikan` = 1  WHERE id = '133541'
#   ________
#   __________[52/293]  At least S2 in any program
#   ____________________  Old len: 8 __ New len: 6 __ WARNING!
#   ____________________  O O O B-Tingkat_pendidikan O O O
#   ____________________  O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='At least S2 in any program',  `label`='O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '135044'
#   ________
#   __________[53/293]  atau S2 Masters Degree / Post Graduate in Mass Communication , Public Relations , Management .
#   ____________________  Old len: 18 __ New len: 16 __ WARNING!
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='atau S2 Masters Degree / Post Graduate in Mass Communication , Public Relations , Management .',  `label`='O B-Tingkat_pendidikan O O O O O O O O O O O O O O',  `space_length`='16',  `tingkat_pendidikan` = 1  WHERE id = '137818'
#   ________
#   __________[54/293]  PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 33 __ New len: 33
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='33',  `tingkat_pendidikan` = 1  WHERE id = '140995'
#   ________
#   __________[55/293]  Maksimal usia 25 tahun ( S1 ) / 26 tahun ( S2 ) .
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O
#   ____________________  O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Maksimal usia 25 tahun ( S1 ) / 26 tahun ( S2 ) .',  `label`='O O O O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '148767'
#   ________
#   __________[56/293]  Diploma Pascasarjana / Magister ( S2 )
#   ____________________  Old len: 9 __ New len: 7 __ WARNING!
#   ____________________  O O O O O B-Tingkat_pendidikan O O
#   ____________________  O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Diploma Pascasarjana / Magister ( S2 )',  `label`='O O O O O B-Tingkat_pendidikan O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '152260'
#   ________
#   __________[57/293]  Lulusan DIII , S1 , S2
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan DIII , S1 , S2',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '152934'
#   ________
#   __________[58/293]  Pendidikan S1 / S2
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / S2',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '155924'
#   ________
#   __________[59/293]  - Berusia maksimal 35 tahun untuk lulusan S2 , dan 40 tahun untuk lulusan S3
#   ____________________  Old len: 17 __ New len: 15 __ WARNING!
#   ____________________  O O O O O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan
#   ____________________  O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Berusia maksimal 35 tahun untuk lulusan S2 , dan 40 tahun untuk lulusan S3',  `label`='O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '159333'
#   ________
#   __________[60/293]  Master ( S2 ) ≥ 3 , 0 c .
#   ____________________  Old len: 12 __ New len: 10 __ WARNING!
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Master ( S2 ) ≥ 3 , 0 c .',  `label`='O O B-Tingkat_pendidikan O O O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '159337'
#   ________
#   __________[61/293]  Pendidikan S1 Ners atau S2 Keperawatan dengan IPK min 3 .
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 Ners atau S2 Keperawatan dengan IPK min 3 .',  `label`='O B-Tingkat_pendidikan O O B-Tingkat_pendidikan O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '166619'
#   ________
#   __________[62/293]  Tingkat Pendidikan / IPK : S1 / S2 , IPK min 3 .
#   ____________________  Old len: 13 __ New len: 13
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Tingkat Pendidikan / IPK : S1 / S2 , IPK min 3 .',  `label`='O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='13',  `tingkat_pendidikan` = 1  WHERE id = '170421'
#   ________
#   __________[63/293]  Yang dapat memberikan gaji diatas UMK , insentif2 , fasilitas2 , pengembangan kemampuan , jenjang karir , budaya kerja & lingkungan kerja yang menyenangkan serta ritual & selebrasi team rutin yang menarik .
#   ____________________  Old len: 35 __ New len: 33 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Yang dapat memberikan gaji diatas UMK , insentif2 , fasilitas2 , pengembangan kemampuan , jenjang karir , budaya kerja & lingkungan kerja yang menyenangkan serta ritual & selebrasi team rutin yang menarik .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='33',  `tingkat_pendidikan` = 1  WHERE id = '175614'
#   ________
#   __________[64/293]  Pendidikan minimal S1 hukum / psikologi ( lebih diutamakan S2 )
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S1 hukum / psikologi ( lebih diutamakan S2 )',  `label`='O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '181585'
#   ________
#   __________[65/293]  Minimal D3 - S2
#   ____________________  Old len: 5 __ New len: 4 __ WARNING!
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal D3 - S2',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '190963'
#   ________
#   __________[66/293]  S1 / S2 Engineering Degree or trade with post graduate qualifications in Asset Management .
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 Engineering Degree or trade with post graduate qualifications in Asset Management .',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '191144'
#   ________
#   __________[67/293]  - Membuat report harian setiap pagi untuk divisi T2 T0 , S1 S2 S3
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan
#   ____________________  O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Membuat report harian setiap pagi untuk divisi T2 T0 , S1 S2 S3',  `label`='O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '191190'
#   ________
#   __________[68/293]  Lulusan S1 / S2 jurusan IT , Engineering , Matematika , Statistika
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 / S2 jurusan IT , Engineering , Matematika , Statistika',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O',  `space_length`='12',  `tingkat_pendidikan` = 1  WHERE id = '192059'
#   ________
#   __________[69/293]  25 ( S2 ) dari skala 4 .
#   ____________________  Old len: 10 __ New len: 8 __ WARNING!
#   ____________________  O O B-Tingkat_pendidikan O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='25 ( S2 ) dari skala 4 .',  `label`='O O B-Tingkat_pendidikan O O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '192063'
#   ________
#   __________[70/293]  Pendidikan minimal S1 Segala Jurusan ( lebih diutamakan S2 )
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S1 Segala Jurusan ( lebih diutamakan S2 )',  `label`='O O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '192392'
#   ________
#   __________[71/293]  S1 graduate from reputable university , preferably S2 graduate with major inTelecommunication , Technology , Computer andother field sciencesDeep knowledge on Sales preferably with some experience in telecommunication technologyStrongknowledge on SMS businessExcellent Oral and Written communication skills
#   ____________________  Old len: 37 __ New len: 37
#   ____________________  B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 graduate from reputable university , preferably S2 graduate with major inTelecommunication , Technology , Computer andother field sciencesDeep knowledge on Sales preferably with some experience in telecommunication technologyStrongknowledge on SMS businessExcellent Oral and Written communication skills',  `label`='B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='37',  `tingkat_pendidikan` = 1  WHERE id = '193554'
#   ________
#   __________[72/293]  S1 Psikologi / Hukum / Management ( S2 lebih diutamakan )
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O
#   ____________________  B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 Psikologi / Hukum / Management ( S2 lebih diutamakan )',  `label`='B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '203993'
#   ________
#   __________[73/293]  S1 / S2 from Accounting or Finance major
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 from Accounting or Finance major',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '214833'
#   ________
#   __________[74/293]  Lebih diutamakan sudah melanjutkan S2 Kesehatan dan Keselamatan Kerja .
#   ____________________  Old len: 12 __ New len: 10 __ WARNING!
#   ____________________  O O O O B-Tingkat_pendidikan O O O O O O
#   ____________________  O O O O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lebih diutamakan sudah melanjutkan S2 Kesehatan dan Keselamatan Kerja .',  `label`='O O O O B-Tingkat_pendidikan O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '221319'
#   ________
#   __________[75/293]  Pendidikan minimal S2
#   ____________________  Old len: 4 __ New len: 3 __ WARNING!
#   ____________________  O O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal S2',  `label`='O O B-Tingkat_pendidikan',  `space_length`='3',  `tingkat_pendidikan` = 1  WHERE id = '224202'
#   ________
#   __________[76/293]  S1 / S2 jurusan Teknologi Pangan
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='S1 / S2 jurusan Teknologi Pangan',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '226791'
#   ________
#   __________[77/293]  Pendidikan S1 Hukum , S2 akan diutamakan
# ...
#   ________
#   __________[280/293]  LulusanS2 / S3 , ProgramStudiSistemInformasi , Informatika
#   ____________________  Old len: 8 __ New len: 7 __ WARNING!
#   ____________________  O O B-Tingkat_pendidikan O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='LulusanS2 / S3 , ProgramStudiSistemInformasi , Informatika',  `label`='O O B-Tingkat_pendidikan O O O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '756243'
#   ________
#   __________[281/293]  LulusanS3 ( Doktor ) lebihdiutamakan , atauMinimalS2programstudiTeknikSipildengankonsentrasiBidangStruktur
#   ____________________  Old len: 8 __ New len: 7 __ WARNING!
#   ____________________  O O O O O O O
#   ____________________  O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='LulusanS3 ( Doktor ) lebihdiutamakan , atauMinimalS2programstudiTeknikSipildengankonsentrasiBidangStruktur',  `label`='O O O O O O O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '757201'
#   ________
#   __________[282/293]  Lulusan S2 / S3 , Program Studi Seni Kuliner
#   ____________________  Old len: 10 __ New len: 9 __ WARNING!
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S2 / S3 , Program Studi Seni Kuliner',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '758062'
#   ________
#   __________[283/293]  Pendidikan terakhir S1 / S2 Hukum
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan terakhir S1 / S2 Hukum',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '767440'
#   ________
#   __________[284/293]  5 - terbuka untuk semua jurusan - diutamakan yang telah mengalami pengalaman mengajar selama 1 th - mempunyai sertifikat pendukung jika ada - menguasai formating skripsi , disertasi , thesis - Pria / Wanita - Berpengalaman - S2 - 25 - 35 Tahun - Terima kandidat tanpa foto diri - Terima kandidat dari mana saja
#   ____________________  Old len: 56 __ New len: 55 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='5 - terbuka untuk semua jurusan - diutamakan yang telah mengalami pengalaman mengajar selama 1 th - mempunyai sertifikat pendukung jika ada - menguasai formating skripsi , disertasi , thesis - Pria / Wanita - Berpengalaman - S2 - 25 - 35 Tahun - Terima kandidat tanpa foto diri - Terima kandidat dari mana saja',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O',  `space_length`='55',  `tingkat_pendidikan` = 1  WHERE id = '775041'
#   ________
#   __________[285/293]  Strong foundation in information security and IT management frameworks and standards , such as ISO27000 series , COBiT , ITIL , SANS20 , PCI - DSS
#   ____________________  Old len: 27 __ New len: 26 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Strong foundation in information security and IT management frameworks and standards , such as ISO27000 series , COBiT , ITIL , SANS20 , PCI - DSS',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='26',  `tingkat_pendidikan` = 1  WHERE id = '787689'
#   ________
#   __________[286/293]  Strong foundation in information security and IT management frameworks and standards , such as ISO27000 series , COBiT , ITIL , SANS20 , PCI - DSS
#   ____________________  Old len: 27 __ New len: 26 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Strong foundation in information security and IT management frameworks and standards , such as ISO27000 series , COBiT , ITIL , SANS20 , PCI - DSS',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='26',  `tingkat_pendidikan` = 1  WHERE id = '789020'
#   ________
#   __________[287/293]  Having experience in implementation of serial communication protocols like ( SPI , I2C , Ethernet , RS232 , Modbus , and so on )
#   ____________________  Old len: 26 __ New len: 24 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Having experience in implementation of serial communication protocols like ( SPI , I2C , Ethernet , RS232 , Modbus , and so on )',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='24',  `tingkat_pendidikan` = 1  WHERE id = '827386'
#   ________
#   __________[288/293]  - Memberikan sosialisasi produk pembiayaan modal kerja / usaha berbasis syariah - Mencari nasabah untuk melakukan peminjaman modal wirausaha - Mendampingi dan menjalin hubungan baik dengan nasabah - Datang ke kelompok pertemuan rutin nasabah untuk menjalankan fungsi sebagai bankir - Bersedia tinggal di mess ( Senin - Jumat ) - Dapat mengendarakan motor Benefit : - Gaji UMK Penempatan - BPJS Lengkap - Disediakan Mess dan fasilitas transportasi - Wanita - Tanpa Pengalaman Bekerja - S2 - 17 - 29 Tahun - Terima kandidat tanpa foto diri - Terima kandidat dari mana saja
#   ____________________  Old len: 95 __ New len: 93 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Memberikan sosialisasi produk pembiayaan modal kerja / usaha berbasis syariah - Mencari nasabah untuk melakukan peminjaman modal wirausaha - Mendampingi dan menjalin hubungan baik dengan nasabah - Datang ke kelompok pertemuan rutin nasabah untuk menjalankan fungsi sebagai bankir - Bersedia tinggal di mess ( Senin - Jumat ) - Dapat mengendarakan motor Benefit : - Gaji UMK Penempatan - BPJS Lengkap - Disediakan Mess dan fasilitas transportasi - Wanita - Tanpa Pengalaman Bekerja - S2 - 17 - 29 Tahun - Terima kandidat tanpa foto diri - Terima kandidat dari mana saja',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O O O',  `space_length`='93',  `tingkat_pendidikan` = 1  WHERE id = '835916'
#   ________
#   __________[289/293]  5 - terbuka untuk semua jurusan - diutamakan yang telah mengalami pengalaman mengajar selama 1 th - mempunyai sertifikat pendukung jika ada - menguasai formating skripsi , disertasi , thesis - Pria / Wanita - Berpengalaman - S2 - 25 - 35 Tahun - Terima kandidat tanpa foto diri - Terima kandidat dari mana saja
#   ____________________  Old len: 56 __ New len: 55 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='5 - terbuka untuk semua jurusan - diutamakan yang telah mengalami pengalaman mengajar selama 1 th - mempunyai sertifikat pendukung jika ada - menguasai formating skripsi , disertasi , thesis - Pria / Wanita - Berpengalaman - S2 - 25 - 35 Tahun - Terima kandidat tanpa foto diri - Terima kandidat dari mana saja',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O',  `space_length`='55',  `tingkat_pendidikan` = 1  WHERE id = '839412'
#   ________
#   __________[290/293]  - Bertanggung jawab dalam memimpin dan bertanggung jawab terhadap seluruh proses kegiatan marketing agar target perusahaan tercapai - Menyusun , mengatur , menganalisis , mengimplementasi dan mengevaluasi manajemen pemasaran , penjualan dan promosi - Melakukan pengawasan dan pengendalian atas seluruh kinerja manajemen pemasaran , penjualan dan promosi - Lulusan / Mahasiswa D3 / S1 / S2 - Laki - laki / Perempuan - Usia 27 - 40 th - Tertarik entrepreneurship - Suka tantangan , kreatif dan bisa bekerja dalam tim
#   ____________________  Old len: 76 __ New len: 81 __ WARNING!
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O B-Jenis_kelamin B-Jenis_kelamin O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Bertanggung jawab dalam memimpin dan bertanggung jawab terhadap seluruh proses kegiatan marketing agar target perusahaan tercapai - Menyusun , mengatur , menganalisis , mengimplementasi dan mengevaluasi manajemen pemasaran , penjualan dan promosi - Melakukan pengawasan dan pengendalian atas seluruh kinerja manajemen pemasaran , penjualan dan promosi - Lulusan / Mahasiswa D3 / S1 / S2 - Laki - laki / Perempuan - Usia 27 - 40 th - Tertarik entrepreneurship - Suka tantangan , kreatif dan bisa bekerja dalam tim',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='81',  `tingkat_pendidikan` = 1  WHERE id = '852659'
#   ________
#   __________[291/293]  - Menawarkan produk - produk Adira Finance kepada nasabah yang sudah ada maupun yang baru - Mendapatkan pesanan dari channel distribution , melakukan initial data melalui MS2 , memverifikasi dan melengkapi dokumen nasabah dan aplikasi kredit - Memantau kemajuan aplikasi kredit nasabah dan mengonfirmasi keputusan kredit kepada dealer dan nasabah - Menginformasikan tanggal jatuh tempo , lokasi pembayaran , dan hal - hal yang perlu diketahui konsumen - Pendidikan min S1 / D3 dari semua jurusan dengan min IPK 2 , 50 - Memiliki pengalaman 1 tahun di bidang yang sama - Terbuka untuk lulusan baru - Usia max 29 tahun - Memahami proses bisnis multifinance dan berorientasi pada target - Mampu mengoperasikan komputer , terutama Ms .
#   ____________________  Old len: 118 __ New len: 118
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Menawarkan produk - produk Adira Finance kepada nasabah yang sudah ada maupun yang baru - Mendapatkan pesanan dari channel distribution , melakukan initial data melalui MS2 , memverifikasi dan melengkapi dokumen nasabah dan aplikasi kredit - Memantau kemajuan aplikasi kredit nasabah dan mengonfirmasi keputusan kredit kepada dealer dan nasabah - Menginformasikan tanggal jatuh tempo , lokasi pembayaran , dan hal - hal yang perlu diketahui konsumen - Pendidikan min S1 / D3 dari semua jurusan dengan min IPK 2 , 50 - Memiliki pengalaman 1 tahun di bidang yang sama - Terbuka untuk lulusan baru - Usia max 29 tahun - Memahami proses bisnis multifinance dan berorientasi pada target - Mampu mengoperasikan komputer , terutama Ms .',  `label`='O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='118',  `tingkat_pendidikan` = 1  WHERE id = '858937'
#   ________
#   __________[292/293]  Min S1 from any major , S2 will be plus
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O
#   ____________________  O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Min S1 from any major , S2 will be plus',  `label`='O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '862153'
#   ________
#   __________[293/293]  - Pria / Wanita - Tanpa Pengalaman Bekerja - S2 - 25 - 35 Tahun - Kandidat wajib upload foto - Terima kandidat dari mana saja
#   ____________________  Old len: 28 __ New len: 26 __ WARNING!
#   ____________________  O O O O O O O O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Pria / Wanita - Tanpa Pengalaman Bekerja - S2 - 25 - 35 Tahun - Kandidat wajib upload foto - Terima kandidat dari mana saja',  `label`='O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan O O O O O O O O O O O O O O O',  `space_length`='26',  `tingkat_pendidikan` = 1  WHERE id = '863082'
#   ________
