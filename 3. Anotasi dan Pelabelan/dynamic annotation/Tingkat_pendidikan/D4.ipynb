# %%
# Import
import sys
sys.path.append('../../')
 
from a_models.annotation import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity      = "jobdescription"  
    ner         = "D4"  
    label       = "B-Tingkat_pendidikan"  
    entitas     = "tingkat_pendidikan"  
    update      = "yes"  
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    wildcard(entity, ner, label, entitas, update, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____wildcard()
#   ______Select  id  , name  , label  from jobdescription where name like '%D4%'
#   ________Total Row(s) : 219
#   ________ner length: 1
#   ________label length: 1
#   __________[1/219]  Pendidikan minimal D4 / S1 :
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal D4 / S1 :',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '6797'
#   ________
#   __________[2/219]  D4 / S1 Teknik Elektro ( Arus Lemah )
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D4 / S1 Teknik Elektro ( Arus Lemah )',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '7425'
#   ________
#   __________[3/219]  Pendidikan minimal SMK / D4 / D3 Teknik Mesin
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal SMK / D4 / D3 Teknik Mesin',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '8357'
#   ________
#   __________[4/219]  Pendidikan D4 / S1 Teknik Lingkungan / K3
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D4 / S1 Teknik Lingkungan / K3',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '11117'
#   ________
#   __________[5/219]  D3 / D4 Akademi Pelayaran ( Tata Laksana Kelabuhanan , Nautika , Teknika ) , S1 Umum
#   ____________________  Old len: 17 __ New len: 17
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 Akademi Pelayaran ( Tata Laksana Kelabuhanan , Nautika , Teknika ) , S1 Umum',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O',  `space_length`='17',  `tingkat_pendidikan` = 1  WHERE id = '11194'
#   ________
#   __________[6/219]  Minimum a Bachelors Degree ( S1 / D4 ) of Management or Marketing education .
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimum a Bachelors Degree ( S1 / D4 ) of Management or Marketing education .',  `label`='O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '11240'
#   ________
#   __________[7/219]  Minimal mahasiswa semester 4 keatas atau Fresh Graduates ( D3 / D4 / S1 )
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal mahasiswa semester 4 keatas atau Fresh Graduates ( D3 / D4 / S1 )',  `label`='O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '16242'
#   ________
#   __________[8/219]  Pendidikan D4 / S1 Teknik Mesin , Teknik Pertanian , TPHP
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D4 / S1 Teknik Mesin , Teknik Pertanian , TPHP',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '16623'
#   ________
#   __________[9/219]  beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 30 __ New len: 30
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='30',  `tingkat_pendidikan` = 1  WHERE id = '16731'
#   ________
#   __________[10/219]  PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 33 __ New len: 33
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='33',  `tingkat_pendidikan` = 1  WHERE id = '21638'
#   ________
#   __________[11/219]  Minimal pendidikan S1 / D4 / D3
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal pendidikan S1 / D4 / D3',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '21922'
#   ________
#   __________[12/219]  D3 / D4 or Bachelor in Engineering .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 or Bachelor in Engineering .',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '23704'
#   ________
#   __________[13/219]  beberapa orang minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Elektro / Teknik Telekomunikasi / Sistem Informasi / Fisika / Matematika / Statistika / Ilmu Komputer / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 41 __ New len: 41
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Elektro / Teknik Telekomunikasi / Sistem Informasi / Fisika / Matematika / Statistika / Ilmu Komputer / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='41',  `tingkat_pendidikan` = 1  WHERE id = '25713'
#   ________
#   __________[14/219]  D4 ( Diploma ) / setara Sarjana ( S1 )
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  B-Tingkat_pendidikan O O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D4 ( Diploma ) / setara Sarjana ( S1 )',  `label`='B-Tingkat_pendidikan O O O O O O O B-Tingkat_pendidikan O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '26122'
#   ________
#   __________[15/219]  Pendidikan terakhir D3 / D4 / S1 semua jurusan
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan terakhir D3 / D4 / S1 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '32564'
#   ________
#   __________[16/219]  Memiliki pendidikan minimal D4 Radiologi atau Radioterapi .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O O O B-Tingkat_pendidikan O O O O
#   ____________________  O O O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Memiliki pendidikan minimal D4 Radiologi atau Radioterapi .',  `label`='O O O B-Tingkat_pendidikan O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '35748'
#   ________
#   __________[17/219]  Lulusan S1 / D4 jurusan Teknik Mesin / Teknik Industri
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 / D4 jurusan Teknik Mesin / Teknik Industri',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '45656'
#   ________
#   __________[18/219]  Usia Maksimal 32 tahun untuk pendidikan D3 / D4 / S1
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Usia Maksimal 32 tahun untuk pendidikan D3 / D4 / S1',  `label`='O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '48239'
#   ________
#   __________[19/219]  - D3 Tourism / cullinary art / Bachelor of Food Technology / D4 Tourism
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- D3 Tourism / cullinary art / Bachelor of Food Technology / D4 Tourism',  `label`='O O B-Tingkat_pendidikan O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '54029'
#   ________
#   __________[20/219]  beberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 29 __ New len: 29
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='29',  `tingkat_pendidikan` = 1  WHERE id = '64623'
#   ________
#   __________[21/219]  Freshgraduate lulusan D3 / D4 / S1
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Freshgraduate lulusan D3 / D4 / S1',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '66568'
#   ________
#   __________[22/219]  DiplomaIV ( D4 ) orBachelorDegree ( S1 ) inFoodProduction , Accounting , Management background from reputable Hotel Institute / University / Institute .
#   ____________________  Old len: 23 __ New len: 23
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='DiplomaIV ( D4 ) orBachelorDegree ( S1 ) inFoodProduction , Accounting , Management background from reputable Hotel Institute / University / Institute .',  `label`='O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O',  `space_length`='23',  `tingkat_pendidikan` = 1  WHERE id = '76666'
#   ________
#   __________[23/219]  SMK / D3 / D4 / S1 Jurusan USAHA PERJALANAN WISATA - TRAVEL AGENT
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='SMK / D3 / D4 / S1 Jurusan USAHA PERJALANAN WISATA - TRAVEL AGENT',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '86297'
#   ________
#   __________[24/219]  Minimal lulusan D4 / S1
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal lulusan D4 / S1',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='5',  `tingkat_pendidikan` = 1  WHERE id = '87249'
#   ________
#   __________[25/219]  MinimalD3 / D4 Elektromedik ( ATEM ) / Teknik Elektro .
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='MinimalD3 / D4 Elektromedik ( ATEM ) / Teknik Elektro .',  `label`='O O B-Tingkat_pendidikan O O O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '87393'
#   ________
#   __________[26/219]  Minimal pendidikan D4 / S1 Teknik Mesin / Teknik Elektro
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal pendidikan D4 / S1 Teknik Mesin / Teknik Elektro',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '90784'
#   ________
#   __________[27/219]  Pendidikan S1 / D4 Teknik Informatika , Teknik Komputer , Sistem Informasi
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / D4 Teknik Informatika , Teknik Komputer , Sistem Informasi',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O',  `space_length`='12',  `tingkat_pendidikan` = 1  WHERE id = '91861'
#   ________
#   __________[28/219]  Pendidikan terakhir D3 / D4 / S1 semua jurusan
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan terakhir D3 / D4 / S1 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '96023'
#   ________
#   __________[29/219]  D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )',  `label`='B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '98432'
#   ________
#   __________[30/219]  SMA , SMU / SMK / STM , Sertifikat Professional , D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )
#   ____________________  Old len: 25 __ New len: 25
#   ____________________  B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='SMA , SMU / SMK / STM , Sertifikat Professional , D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )',  `label`='B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O',  `space_length`='25',  `tingkat_pendidikan` = 1  WHERE id = '99948'
#   ________
#   __________[31/219]  Pendidikan D3 , D4 / S1 Teknik Industri , Teknik Mesin
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 , D4 / S1 Teknik Industri , Teknik Mesin',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '104508'
#   ________
#   __________[32/219]  Pendidikan D3 , D4 / S1 Teknik Industri , Teknik Mesin
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 , D4 / S1 Teknik Industri , Teknik Mesin',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '104892'
#   ________
#   __________[33/219]  Pendidikan Minimal D4 atau S1 Biomedis / Teknik Elektromedik / Farmasi
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan Minimal D4 atau S1 Biomedis / Teknik Elektromedik / Farmasi',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '106207'
#   ________
#   __________[34/219]  Pendidikan D3 / D4 / S1 Teknik Elektro
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 / D4 / S1 Teknik Elektro',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '111969'
#   ________
#   __________[35/219]  Pendidikan minimal SMK / D4 / D3 Teknik Mesin
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal SMK / D4 / D3 Teknik Mesin',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '119327'
#   ________
#   __________[36/219]  D4 / S1 Teknik Elektro ( Arus Lemah )
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D4 / S1 Teknik Elektro ( Arus Lemah )',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '119961'
#   ________
#   __________[37/219]  Pendidikan minimal D4 / S1 :
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal D4 / S1 :',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '120631'
#   ________
#   __________[38/219]  Pendidikan D3 / D4 / S1 Teknik Elektro
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 / D4 / S1 Teknik Elektro',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '123220'
#   ________
#   __________[39/219]  Lulusan S1 / D4 dari Sekolah Tinggi / Akademi Ilmu Pelayaran terkemuka
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 / D4 dari Sekolah Tinggi / Akademi Ilmu Pelayaran terkemuka',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O',  `space_length`='12',  `tingkat_pendidikan` = 1  WHERE id = '123419'
#   ________
#   __________[40/219]  Pendidikan Minimal D3 / D4 , Teknik Tekstil ( memiliki pengalaman Minimal 2 tahun dibidang yang sama )
#   ____________________  Old len: 18 __ New len: 18
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan Minimal D3 / D4 , Teknik Tekstil ( memiliki pengalaman Minimal 2 tahun dibidang yang sama )',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O',  `space_length`='18',  `tingkat_pendidikan` = 1  WHERE id = '125961'
#   ________
#   __________[41/219]  Pendidikan D4 / S1 Teknik Lingkungan / K3
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D4 / S1 Teknik Lingkungan / K3',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '127887'
#   ________
#   __________[42/219]  D3 / D4 Akademi Pelayaran ( Tata Laksana Kelabuhanan , Nautika , Teknika ) , S1 Umum
#   ____________________  Old len: 17 __ New len: 17
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 Akademi Pelayaran ( Tata Laksana Kelabuhanan , Nautika , Teknika ) , S1 Umum',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O',  `space_length`='17',  `tingkat_pendidikan` = 1  WHERE id = '127951'
#   ________
#   __________[43/219]  Minimum a Bachelors Degree ( S1 / D4 ) of Management or Marketing education .
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimum a Bachelors Degree ( S1 / D4 ) of Management or Marketing education .',  `label`='O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '127991'
#   ________
#   __________[44/219]  Minimal mahasiswa semester 4 keatas atau Fresh Graduates ( D3 / D4 / S1 )
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal mahasiswa semester 4 keatas atau Fresh Graduates ( D3 / D4 / S1 )',  `label`='O O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '133236'
#   ________
#   __________[45/219]  Pendidikan D4 / S1 Teknik Mesin , Teknik Pertanian , TPHP
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D4 / S1 Teknik Mesin , Teknik Pertanian , TPHP',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '133392'
#   ________
#   __________[46/219]  beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 30 __ New len: 30
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='30',  `tingkat_pendidikan` = 1  WHERE id = '133541'
#   ________
#   __________[47/219]  PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 33 __ New len: 33
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='33',  `tingkat_pendidikan` = 1  WHERE id = '140995'
#   ________
#   __________[48/219]  - Pendidikan D4 / S1
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O B-Tingkat_pendidikan B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- Pendidikan D4 / S1',  `label`='O O B-Tingkat_pendidikan B-Tingkat_pendidikan O',  `space_length`='5',  `tingkat_pendidikan` = 1  WHERE id = '147831'
#   ________
#   __________[49/219]  D4 ( Diploma ) / setara Sarjana ( S1 )
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  B-Tingkat_pendidikan O O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D4 ( Diploma ) / setara Sarjana ( S1 )',  `label`='B-Tingkat_pendidikan O O O O O O O B-Tingkat_pendidikan O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '152259'
#   ________
#   __________[50/219]  Memiliki pendidikan minimal D4 Radiologi atau Radioterapi .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O O O B-Tingkat_pendidikan O O O O
#   ____________________  O O O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Memiliki pendidikan minimal D4 Radiologi atau Radioterapi .',  `label`='O O O B-Tingkat_pendidikan O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '154766'
#   ________
#   __________[51/219]  - D4 / S1 teknik elektro
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O B-Tingkat_pendidikan B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O B-Tingkat_pendidikan B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- D4 / S1 teknik elektro',  `label`='O B-Tingkat_pendidikan B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '161826'
#   ________
#   __________[52/219]  Minimal lulusan SMA / sederajat atau D3 / D4 di bidang perhotelan .
#   ____________________  Old len: 13 __ New len: 13
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal lulusan SMA / sederajat atau D3 / D4 di bidang perhotelan .',  `label`='O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='13',  `tingkat_pendidikan` = 1  WHERE id = '163757'
#   ________
#   __________[53/219]  Lulusan S1 / D4 jurusan Teknik Mesin / Teknik Industri
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 / D4 jurusan Teknik Mesin / Teknik Industri',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '166807'
#   ________
#   __________[54/219]  Usia Maksimal 32 tahun untuk pendidikan D3 / D4 / S1
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Usia Maksimal 32 tahun untuk pendidikan D3 / D4 / S1',  `label`='O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '180707'
#   ________
#   __________[55/219]  - D3 Tourism / cullinary art / Bachelor of Food Technology / D4 Tourism
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='- D3 Tourism / cullinary art / Bachelor of Food Technology / D4 Tourism',  `label`='O O B-Tingkat_pendidikan O O O O O O O O O B-Tingkat_pendidikan B-Tingkat_pendidikan',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '182500'
#   ________
#   __________[56/219]  Pendidikan D3 / D4
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 / D4',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '185030'
#   ________
#   __________[57/219]  Pendidikan minimal SMA / Sederajat , D3 / D4 ( Peternakan , Kesehatan Hewan )
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal SMA / Sederajat , D3 / D4 ( Peternakan , Kesehatan Hewan )',  `label`='O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '192915'
#   ________
#   __________[58/219]  Lulusan D3 / D4 Okupasi Terapi
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan D3 / D4 Okupasi Terapi',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '200389'
#   ________
#   __________[59/219]  Minimal lulusan D4 / S1
#   ____________________  Old len: 5 __ New len: 5
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal lulusan D4 / S1',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='5',  `tingkat_pendidikan` = 1  WHERE id = '213667'
#   ________
#   __________[60/219]  DiplomaIV ( D4 ) orBachelorDegree ( S1 ) inFoodProduction , Accounting , Management background from reputable Hotel Institute / University / Institute .
#   ____________________  Old len: 23 __ New len: 23
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='DiplomaIV ( D4 ) orBachelorDegree ( S1 ) inFoodProduction , Accounting , Management background from reputable Hotel Institute / University / Institute .',  `label`='O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O',  `space_length`='23',  `tingkat_pendidikan` = 1  WHERE id = '214058'
#   ________
#   __________[61/219]  Pendidikan minimal D4 / S1 Kesehatan Masyarakat , Teknik Industri
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan minimal D4 / S1 Kesehatan Masyarakat , Teknik Industri',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '215240'
#   ________
#   __________[62/219]  Lulusan D3 / D4 paramedik veteriner
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan D3 / D4 paramedik veteriner',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '218151'
#   ________
#   __________[63/219]  Pendidikan S1 / D4 Teknik Informatika , Teknik Komputer , Sistem Informasi
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan S1 / D4 Teknik Informatika , Teknik Komputer , Sistem Informasi',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O',  `space_length`='12',  `tingkat_pendidikan` = 1  WHERE id = '219471'
#   ________
#   __________[64/219]  SMK / D3 / D4 / S1 Jurusan USAHA PERJALANAN WISATA - TRAVEL AGENT
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='SMK / D3 / D4 / S1 Jurusan USAHA PERJALANAN WISATA - TRAVEL AGENT',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '220699'
#   ________
#   __________[65/219]  MinimalD3 / D4 Elektromedik ( ATEM ) / Teknik Elektro .
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='MinimalD3 / D4 Elektromedik ( ATEM ) / Teknik Elektro .',  `label`='O O B-Tingkat_pendidikan O O O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '223487'
#   ________
#   __________[66/219]  SMA , SMU / SMK / STM , Sertifikat Professional , D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )
#   ____________________  Old len: 25 __ New len: 25
#   ____________________  B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='SMA , SMU / SMK / STM , Sertifikat Professional , D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )',  `label`='B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O',  `space_length`='25',  `tingkat_pendidikan` = 1  WHERE id = '235438'
#   ________
#   __________[67/219]  Pendidikan SMA / k , D1 / D3 / D4
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan SMA / k , D1 / D3 / D4',  `label`='O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '236183'
#   ________
#   __________[68/219]  Pendidikan SMA / k , D1 / D3 / D4
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan SMA / k , D1 / D3 / D4',  `label`='O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '245870'
#   ________
#   __________[69/219]  Pendidikan terakhir D3 / D4 / S1 semua jurusan
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan terakhir D3 / D4 / S1 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '248019'
#   ________
#   __________[70/219]  Pendidikan D3 Survey Pemetaan / D4 Survey Pemetaan / S1 Teknik Geodesi / Teknik Sipil
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O
#   ____________________  O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 Survey Pemetaan / D4 Survey Pemetaan / S1 Teknik Geodesi / Teknik Sipil',  `label`='O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '250469'
#   ________
#   __________[71/219]  Pendidikan D3 / D4 / S1 Teknik Elektro
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D3 / D4 / S1 Teknik Elektro',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '250913'
#   ________
#   __________[72/219]  Pendidikan SMA / k , D1 / D3 / D4
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan SMA / k , D1 / D3 / D4',  `label`='O B-Tingkat_pendidikan O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '254102'
#   ________
#   __________[73/219]  Lulusan Akuntansi S1 / D4 / D3 , IPK 3 .
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
# ...
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan terakhir D3 / D4 / S1 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '687705'
#   ________
#   __________[197/219]  Freshgraduate lulusan D3 / D4 / S1
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Freshgraduate lulusan D3 / D4 / S1',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '689812'
#   ________
#   __________[198/219]  Lulusan S1 / D4 jurusan Teknik Mesin / Teknik Industri
#   ____________________  Old len: 10 __ New len: 10
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 / D4 jurusan Teknik Mesin / Teknik Industri',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='10',  `tingkat_pendidikan` = 1  WHERE id = '696576'
#   ________
#   __________[199/219]  Minimal lulusan SMA / sederajat atau D3 / D4 di bidang perhotelan .
#   ____________________  Old len: 13 __ New len: 13
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   ____________________  O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal lulusan SMA / sederajat atau D3 / D4 di bidang perhotelan .',  `label`='O O B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O',  `space_length`='13',  `tingkat_pendidikan` = 1  WHERE id = '707839'
#   ________
#   __________[200/219]  Lulusan D3 / D4 / S1 Kebidanan
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan D3 / D4 / S1 Kebidanan',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '718762'
#   ________
#   __________[201/219]  Pendidikan terakhir D3 / D4 / S1 semua jurusan
#   ____________________  Old len: 9 __ New len: 9
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan terakhir D3 / D4 / S1 semua jurusan',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='9',  `tingkat_pendidikan` = 1  WHERE id = '719167'
#   ________
#   __________[202/219]  D3 / D4 or Bachelor in Engineering .
#   ____________________  Old len: 8 __ New len: 8
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 or Bachelor in Engineering .',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='8',  `tingkat_pendidikan` = 1  WHERE id = '719304'
#   ________
#   __________[203/219]  Usia Maksimal 32 tahun untuk pendidikan D3 / D4 / S1
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Usia Maksimal 32 tahun untuk pendidikan D3 / D4 / S1',  `label`='O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '720321'
#   ________
#   __________[204/219]  beberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 29 __ New len: 29
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='29',  `tingkat_pendidikan` = 1  WHERE id = '720644'
#   ________
#   __________[205/219]  D3 / D4 / S1 Fisioterapi yang memiliki STR Aktif .
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 / S1 Fisioterapi yang memiliki STR Aktif .',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '721179'
#   ________
#   __________[206/219]  beberapa orang minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Elektro / Teknik Telekomunikasi / Sistem Informasi / Fisika / Matematika / Statistika / Ilmu Komputer / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 41 __ New len: 41
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='beberapa orang minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Elektro / Teknik Telekomunikasi / Sistem Informasi / Fisika / Matematika / Statistika / Ilmu Komputer / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',  `space_length`='41',  `tingkat_pendidikan` = 1  WHERE id = '725556'
#   ________
#   __________[207/219]  PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :
#   ____________________  Old len: 33 __ New len: 33
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   ____________________  O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='PT Sharing Vision Indonesiamasih membutuhkanbeberapa talent minimal S1 / D4 / S2 dari Teknik Informatika / Sistem Teknologi Informasi / Teknik Komputer / Teknik Elektro / Engineer lainnya , untuk posisi sebagai :',  `label`='O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O O O O O O O O O O',  `space_length`='33',  `tingkat_pendidikan` = 1  WHERE id = '727273'
#   ________
#   __________[208/219]  Minimal pendidikan S1 / D4 / D3
#   ____________________  Old len: 7 __ New len: 7
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   ____________________  O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal pendidikan S1 / D4 / D3',  `label`='O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan',  `space_length`='7',  `tingkat_pendidikan` = 1  WHERE id = '729410'
#   ________
#   __________[209/219]  D3 / D4 , Bachelors Degree in Engineering ( Electrical / Electronic ) or equivalent
#   ____________________  Old len: 15 __ New len: 15
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 , Bachelors Degree in Engineering ( Electrical / Electronic ) or equivalent',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O',  `space_length`='15',  `tingkat_pendidikan` = 1  WHERE id = '729804'
#   ________
#   __________[210/219]  SMA , SMU / SMK / STM , Sertifikat Professional , D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )
#   ____________________  Old len: 25 __ New len: 25
#   ____________________  B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='SMA , SMU / SMK / STM , Sertifikat Professional , D3 ( Diploma ) , D4 ( Diploma ) , Sarjana ( S1 )',  `label`='B-Tingkat_pendidikan O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O O O O B-Tingkat_pendidikan O O O O O O B-Tingkat_pendidikan O',  `space_length`='25',  `tingkat_pendidikan` = 1  WHERE id = '730220'
#   ________
#   __________[211/219]  D3 / D4 Akademi Pelayaran ( Tata Laksana Kelabuhanan , Nautika , Teknika ) , S1 Umum
#   ____________________  Old len: 17 __ New len: 17
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O
#   ____________________  B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='D3 / D4 Akademi Pelayaran ( Tata Laksana Kelabuhanan , Nautika , Teknika ) , S1 Umum',  `label`='B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O O O O O O B-Tingkat_pendidikan O',  `space_length`='17',  `tingkat_pendidikan` = 1  WHERE id = '731637'
#   ________
#   __________[212/219]  Pendidikan D4 / S1 Teknik Mesin , Teknik Pertanian , TPHP
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Pendidikan D4 / S1 Teknik Mesin , Teknik Pertanian , TPHP',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '734081'
#   ________
#   __________[213/219]  Minimal lulusan D4 Sipil
#   ____________________  Old len: 4 __ New len: 4
#   ____________________  O O B-Tingkat_pendidikan O
#   ____________________  O O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Minimal lulusan D4 Sipil',  `label`='O O B-Tingkat_pendidikan O',  `space_length`='4',  `tingkat_pendidikan` = 1  WHERE id = '734331'
#   ________
#   __________[214/219]  Lulusan D3 / D4 / S1 Kebidanan dan Keperawatan / Ners
#   ____________________  Old len: 11 __ New len: 11
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan D3 / D4 / S1 Kebidanan dan Keperawatan / Ners',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O O O O',  `space_length`='11',  `tingkat_pendidikan` = 1  WHERE id = '739948'
#   ________
#   __________[215/219]  Lulusan D4 atau D3 Terapi Okupasi
#   ____________________  Old len: 6 __ New len: 6
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   ____________________  O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan D4 atau D3 Terapi Okupasi',  `label`='O B-Tingkat_pendidikan O B-Tingkat_pendidikan O O',  `space_length`='6',  `tingkat_pendidikan` = 1  WHERE id = '741881'
#   ________
#   __________[216/219]  Lulusan S1 Teknik Mesin , Teknik Otomotif , danTeknik Elektro dan D4Teknik Alat Berat
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 Teknik Mesin , Teknik Otomotif , danTeknik Elektro dan D4Teknik Alat Berat',  `label`='O B-Tingkat_pendidikan O O O O O O O O O O O O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '797993'
#   ________
#   __________[217/219]  Lulusan S1 Teknik Mesin , Teknik Otomotif , danTeknik Elektro dan D4Teknik Alat Berat
#   ____________________  Old len: 14 __ New len: 14
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O
#   ____________________  O B-Tingkat_pendidikan O O O O O O O O O O O O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Lulusan S1 Teknik Mesin , Teknik Otomotif , danTeknik Elektro dan D4Teknik Alat Berat',  `label`='O B-Tingkat_pendidikan O O O O O O O O O O O O',  `space_length`='14',  `tingkat_pendidikan` = 1  WHERE id = '824522'
#   ________
#   __________[218/219]  Bachelors degree in IT or related field ( S1 / D4 )
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Bachelors degree in IT or related field ( S1 / D4 )',  `label`='O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='12',  `tingkat_pendidikan` = 1  WHERE id = '832971'
#   ________
#   __________[219/219]  Bachelors degree in IT or related field ( S1 / D4 )
#   ____________________  Old len: 12 __ New len: 12
#   ____________________  O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   ____________________  O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O
#   __________updated_data_val()
#   ____________UPDATE `jobdescription` SET  `name`='Bachelors degree in IT or related field ( S1 / D4 )',  `label`='O O O O O O O O B-Tingkat_pendidikan O B-Tingkat_pendidikan O',  `space_length`='12',  `tingkat_pendidikan` = 1  WHERE id = '834014'
#   ________
