# %%
# Import
import sys
sys.path.append('../../')
 
from a_models.dynamic_annotation_jobtitle import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------     
    space = "  __"  
    # --------------------------------------------------  
    printx          = 'no'
    updatex         = 'yes'
    # --------------------------------------------------  
    dynamic_wildcard(printx, updatex, space)
    # --------------------------------------------------   
    print(space + "__End", flush=True) 
    ####################################################
# Out:
#   ____dynamic_wildcard()
#   ______Select  id  , nama  , label  from anotasi_jobtitle  where done is null  and label is not null
#   ________Total Row(s) : 25
#   __________[1/25]  #364 __ TS Suites Seminyak __ B-Penempatan_gedung I-Penempatan_gedung I-Penempatan_gedung
#   __________dynamic()
#   ____________entity: TS Suites Seminyak
#   ____________split length: 3
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "TS"  and "penempatan_gedung"  != "B"  order by id asc
#   __________________Total Row(s) : 6
#   __________________round_10_perc Row(s) : 1
#   ____________________[1/6]  #1549 __ TS __ 0
#   __________________________[1/1]  #1550 __ Suites __ nte: Suites __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #1551 __ Seminyak __ nte: Seminyak __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 1549 1550 1551  __ B-Penempatan_gedung I-Penempatan_gedung I-Penempatan_gedung
#   __________________________________updated_data_dynamic() 1549 __ B-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'B'  WHERE id = 1549
#   __________________________________updated_data_dynamic() 1550 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 1550
#   __________________________________updated_data_dynamic() 1551 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 1551
#   __________________
#   ____________________[2/6]  #7545 __ TS __ 0
#   __________________________[1/1]  #7546 __ Systems __ nte: Suites __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[3/6]  #20931 __ TS __ 0
#   __________________________[1/1]  #20932 __ Suites __ nte: Suites __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #20933 __ Seminyak __ nte: Seminyak __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 20931 20932 20933  __ B-Penempatan_gedung I-Penempatan_gedung I-Penempatan_gedung
#   __________________________________updated_data_dynamic() 20931 __ B-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'B'  WHERE id = 20931
#   __________________________________updated_data_dynamic() 20932 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 20932
#   __________________________________updated_data_dynamic() 20933 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 20933
#   __________________
#   ____________________[4/6]  #25533 __ TS __ 0
#   __________________________[1/1]  #25534 __ Suites __ nte: Suites __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #25535 __ Seminyak __ nte: Seminyak __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 25533 25534 25535  __ B-Penempatan_gedung I-Penempatan_gedung I-Penempatan_gedung
#   __________________________________updated_data_dynamic() 25533 __ B-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'B'  WHERE id = 25533
#   __________________________________updated_data_dynamic() 25534 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 25534
#   __________________________________updated_data_dynamic() 25535 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 25535
#   __________________
#   ____________________[5/6]  #32554 __ TS __ 0
#   __________________________[1/1]  #32555 __ Systems __ nte: Suites __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[6/6]  #49453 __ TS __ 0
#   __________________________[1/1]  #49454 __ Suites __ nte: Suites __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #49455 __ Seminyak __ nte: Seminyak __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 49453 49454 49455  __ B-Penempatan_gedung I-Penempatan_gedung I-Penempatan_gedung
#   __________________________________updated_data_dynamic() 49453 __ B-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'B'  WHERE id = 49453
#   __________________________________updated_data_dynamic() 49454 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 49454
#   __________________________________updated_data_dynamic() 49455 __ I-Penempatan_gedung
#   ____________________________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'I'  WHERE id = 49455
#   __________________
#   __________[2/25]  #365 __ Pandaan __ B-Penempatan_kecamatan
#   __________dynamic()
#   ____________entity: Pandaan
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kecamatan` = 'B'  where name like "Pandaan"
#   __________[3/25]  #366 __ URGENT __ B-keterangan_pekerjaan
#   __________dynamic()
#   ____________entity: URGENT
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `keterangan_pekerjaan` = 'B'  where name like "URGENT"
#   __________[4/25]  #367 __ Kalimantan tengah __ B-Penempatan_provinsi I-Penempatan_provinsi
#   __________dynamic()
#   ____________entity: Kalimantan tengah
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "Kalimantan"  and "penempatan_provinsi"  != "B"  order by id asc
#   __________________Total Row(s) : 147
#   __________________round_10_perc Row(s) : 15
#   ____________________[1/147]  #398 __ Kalimantan __ 0
#   __________________________[1/1]  #399 __ Timur __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[15/147]  #17321 __ Kalimantan __ 0
#   __________________________[1/1]  #17322 __ Audit __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[30/147]  #33255 __ Kalimantan __ 0
#   __________________________[1/1]  #33256 __ Timur __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[45/147]  #51169 __ KALIMANTAN __ 0
#   __________________________[1/1]  #51170 __ BARAT __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[60/147]  #64896 __ Kalimantan __ 0
#   __________________________[1/1]  #64897 __ Selatan __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[75/147]  #80278 __ Kalimantan __ 0
#   __________________________[1/1]  #80279 __ Tengah __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________________split_ID() 80278 80279  __ B-Penempatan_provinsi I-Penempatan_provinsi
#   ____________________________updated_data_dynamic() 80278 __ B-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'B'  WHERE id = 80278
#   ____________________________updated_data_dynamic() 80279 __ I-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'I'  WHERE id = 80279
#   __________________
#   ____________________[90/147]  #105128 __ Kalimantan __ 0
#   __________________________[1/1]  #105129 __ Admin __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[105/147]  #120330 __ Kalimantan __ 0
#   __________________________[1/1]  #120331 __ Selatan __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[120/147]  #140858 __ Kalimantan __ 0
#   __________________________[1/1]  #140859 __ , __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[135/147]  #162652 __ Kalimantan __ 0
#   __________________________[1/1]  #162653 __ Timur __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   __________[5/25]  #368 __ Seruyan __ B-Penempatan_kota
#   __________dynamic()
#   ____________entity: Seruyan
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kota` = 'B'  where name like "Seruyan"
#   __________[6/25]  #369 __ Indralaya __ B-Penempatan_kecamatan
#   __________dynamic()
#   ____________entity: Indralaya
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kecamatan` = 'B'  where name like "Indralaya"
#   __________[7/25]  #370 __ Jawa tengah __ B-Penempatan_provinsi I-Penempatan_provinsi
#   __________dynamic()
#   ____________entity: Jawa tengah
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "Jawa"  and "penempatan_provinsi"  != "B"  order by id asc
#   __________________Total Row(s) : 231
#   __________________round_10_perc Row(s) : 23
#   ____________________[1/231]  #700 __ Jawa __ 0
#   __________________________[1/1]  #701 __ Timur __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[23/231]  #15198 __ Jawa __ 0
#   __________________________[1/1]  #15199 __ Timur __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[46/231]  #32783 __ Jawa __ 0
#   __________________________[1/1]  #32784 __ ) __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[69/231]  #44534 __ Jawa __ 0
#   __________________________[1/1]  #44535 __ Barat __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[92/231]  #62903 __ Jawa __ 0
#   __________________________[1/1]  #62904 __ Timur __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[115/231]  #87252 __ JAWA __ 0
#   __________________________[1/1]  #87253 __ BARAT __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[138/231]  #97351 __ Jawa __ 0
#   __________________________[1/1]  #97352 __ Tengah __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________________split_ID() 97351 97352  __ B-Penempatan_provinsi I-Penempatan_provinsi
#   ____________________________updated_data_dynamic() 97351 __ B-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'B'  WHERE id = 97351
#   ____________________________updated_data_dynamic() 97352 __ I-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'I'  WHERE id = 97352
#   __________________
#   ____________________[161/231]  #114319 __ JAWA __ 0
#   __________________________[1/1]  #114320 __ BARAT __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[184/231]  #131832 __ Jawa __ 0
#   __________________________[1/1]  #131833 __ Tengah __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________________split_ID() 131832 131833  __ B-Penempatan_provinsi I-Penempatan_provinsi
#   ____________________________updated_data_dynamic() 131832 __ B-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'B'  WHERE id = 131832
#   ____________________________updated_data_dynamic() 131833 __ I-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'I'  WHERE id = 131833
#   __________________
#   ____________________[207/231]  #146983 __ JAWA __ 0
#   __________________________[1/1]  #146984 __ TIMUR __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[230/231]  #172955 __ Jawa __ 0
#   __________________________[1/1]  #172956 __ Barat __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   __________[8/25]  #371 __ Kemyoran __ B-Penempatan_kecamatan
#   __________dynamic()
#   ____________entity: Kemyoran
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kecamatan` = 'B'  where name like "Kemyoran"
#   __________[9/25]  #372 __ CHIEF __ B-Jabatan
#   __________dynamic()
#   ____________entity: CHIEF
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `jabatan` = 'B'  where name like "CHIEF"
#   __________[10/25]  #373 __ Kemang __ B-Penempatan_kecamatan
#   __________dynamic()
#   ____________entity: Kemang
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kecamatan` = 'B'  where name like "Kemang"
#   __________[11/25]  #374 __ Hybrid working __ B-Cara_kerja I-Cara_kerja
#   __________dynamic()
#   ____________entity: Hybrid working
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "Hybrid"  and "cara_kerja"  != "B"  order by id asc
#   __________________Total Row(s) : 42
#   __________________round_10_perc Row(s) : 4
#   ____________________[1/42]  #2392 __ Hybrid __ 0
#   __________________________[1/1]  #2393 __ Working __ nte: working __ csX: 1 __ lsX: 2
#   __________________________split_ID() 2392 2393  __ B-Cara_kerja I-Cara_kerja
#   ____________________________updated_data_dynamic() 2392 __ B-Cara_kerja
#   ______________________________UPDATE `dataset_jobtitle` SET  `cara_kerja` = 'B'  WHERE id = 2392
#   ____________________________updated_data_dynamic() 2393 __ I-Cara_kerja
#   ______________________________UPDATE `dataset_jobtitle` SET  `cara_kerja` = 'I'  WHERE id = 2393
#   __________________
#   ____________________[4/42]  #27402 __ Hybrid __ 0
#   __________________________[1/1]  #27403 __ Working __ nte: working __ csX: 1 __ lsX: 2
#   __________________________split_ID() 27402 27403  __ B-Cara_kerja I-Cara_kerja
#   ____________________________updated_data_dynamic() 27402 __ B-Cara_kerja
#   ______________________________UPDATE `dataset_jobtitle` SET  `cara_kerja` = 'B'  WHERE id = 27402
#   ____________________________updated_data_dynamic() 27403 __ I-Cara_kerja
#   ______________________________UPDATE `dataset_jobtitle` SET  `cara_kerja` = 'I'  WHERE id = 27403
#   __________________
#   ____________________[8/42]  #90856 __ HYBRID __ 0
#   __________________________[1/1]  #90857 __ ) __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[12/42]  #154431 __ Hybrid __ 0
#   __________________________[1/1]  #154432 __ Jabatan __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[16/42]  #160276 __ Hybrid __ 0
#   __________________________[1/1]  #160277 __ Asst __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[20/42]  #161719 __ Hybrid __ 0
#   __________________________[1/1]  #161720 __ ) __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[24/42]  #162166 __ Hybrid __ 0
#   __________________________[1/1]  #162167 __ ) __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[28/42]  #166948 __ Hybrid __ 0
#   __________________________[1/1]  #166949 __ ) __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[32/42]  #169064 __ Hybrid __ 0
#   __________________________[1/1]  #169065 __ ) __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[36/42]  #170037 __ Hybrid __ 0
#   __________________________[1/1]  #170038 __ Jakarta __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[40/42]  #171304 __ Hybrid __ 0
#   __________________________[1/1]  #171305 __ Inspector __ nte: working __ csX: 1 __ lsX: 2
#   __________________
#   __________[12/25]  #375 __ URGENTLY __ B-keterangan_pekerjaan
#   __________dynamic()
#   ____________entity: URGENTLY
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `keterangan_pekerjaan` = 'B'  where name like "URGENTLY"
#   __________[13/25]  #376 __ Dadap __ B-Penempatan_kelurahan
#   __________dynamic()
#   ____________entity: Dadap
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kelurahan` = 'B'  where name like "Dadap"
#   __________[14/25]  #377 __ Tanjung pandan __ B-Penempatan_kota I-Penempatan_kota
#   __________dynamic()
#   ____________entity: Tanjung pandan
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "Tanjung"  and "penempatan_kota"  != "B"  order by id asc
#   __________________Total Row(s) : 24
#   __________________round_10_perc Row(s) : 2
#   ____________________[1/24]  #1497 __ Tanjung __ 0
#   __________________________[1/1]  #1498 __ ) __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[2/24]  #3017 __ Tanjung __ 0
#   __________________________[1/1]  #3018 __ Pandan __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________________split_ID() 3017 3018  __ B-Penempatan_kota I-Penempatan_kota
#   ____________________________updated_data_dynamic() 3017 __ B-Penempatan_kota
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_kota` = 'B'  WHERE id = 3017
#   ____________________________updated_data_dynamic() 3018 __ I-Penempatan_kota
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_kota` = 'I'  WHERE id = 3018
#   __________________
#   ____________________[4/24]  #18939 __ Tanjung __ 0
#   __________________________[1/1]  #18940 __ Redeb __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[6/24]  #24339 __ Tanjung __ 0
#   __________________________[1/1]  #24340 __ ) __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[8/24]  #28085 __ Tanjung __ 0
#   __________________________[1/1]  #28086 __ Pandan __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________________split_ID() 28085 28086  __ B-Penempatan_kota I-Penempatan_kota
#   ____________________________updated_data_dynamic() 28085 __ B-Penempatan_kota
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_kota` = 'B'  WHERE id = 28085
#   ____________________________updated_data_dynamic() 28086 __ I-Penempatan_kota
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_kota` = 'I'  WHERE id = 28086
#   __________________
#   ____________________[10/24]  #38897 __ Tanjung __ 0
#   __________________________[1/1]  #38898 __ Balai __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[12/24]  #49282 __ Tanjung __ 0
#   __________________________[1/1]  #49283 __ Duren __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[14/24]  #56724 __ Tanjung __ 0
#   __________________________[1/1]  #56725 __ Pinang __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[16/24]  #64172 __ Tanjung __ 0
#   __________________________[1/1]  #64173 __ Morawa __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[18/24]  #103497 __ Tanjung __ 0
#   __________________________[1/1]  #103498 __ Priok __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[20/24]  #124001 __ Tanjung __ 0
#   __________________________[1/1]  #124002 __ Redeb __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[22/24]  #143950 __ Tanjung __ 0
#   __________________________[1/1]  #143951 __ Pinang __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[24/24]  #150751 __ Tanjung __ 0
#   __________________________[1/1]  #150752 __ Barat __ nte: pandan __ csX: 1 __ lsX: 2
#   __________________
#   __________[15/25]  #378 __ cengkareng __ B-Penempatan_kecamatan
#   __________dynamic()
#   ____________entity: cengkareng
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kecamatan` = 'B'  where name like "cengkareng"
#   __________[16/25]  #380 __ Sulawesi __ B-Penempatan_pulau
#   __________dynamic()
#   ____________entity: Sulawesi
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_pulau` = 'B'  where name like "Sulawesi"
#   __________[17/25]  #381 __ FATMAWATI __ B-Penempatan_kawasan
#   __________dynamic()
#   ____________entity: FATMAWATI
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_kawasan` = 'B'  where name like "FATMAWATI"
#   __________[18/25]  #382 __ Jakarta Barat __ B-Penempatan_kota I-Penempatan_kota
#   __________dynamic()
#   ____________entity: Jakarta Barat
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "Jakarta"  and "penempatan_kota"  != "B"  order by id asc
#   __________________Total Row(s) : 746
#   __________________round_10_perc Row(s) : 75
#   ____________________[1/746]  #184 __ Jakarta __ 0
#   __________________________[1/1]  #185 __ ) __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[75/746]  #15264 __ Jakarta __ 0
#   __________________________[1/1]  #15265 __ ) __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[150/746]  #31168 __ Jakarta __ 0
#   __________________________[1/1]  #31169 __ ) __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[225/746]  #49760 __ Jakarta __ 0
#   __________________________[1/1]  #49761 __ Selatan __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[300/746]  #68932 __ Jakarta __ 0
#   __________________________[1/1]  #68933 __ Safety __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[375/746]  #89818 __ Jakarta __ 0
#   __________________________[1/1]  #89819 __ ) __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[450/746]  #105549 __ Jakarta __ 0
#   __________________________[1/1]  #105550 __ Foreman __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[525/746]  #126376 __ JAKARTA __ 0
#   __________________________[1/1]  #126377 __ ) __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[600/746]  #142010 __ JAKARTA __ 0
#   __________________________[1/1]  #142011 __ Admin __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[675/746]  #159328 __ Jakarta __ 0
#   __________________________[1/1]  #159329 __ Timur __ nte: Barat __ csX: 1 __ lsX: 2
#   __________________
#   __________[19/25]  #384 __ . NET __ B-Keterampilan_teknis I-Keterampilan_teknis
#   __________dynamic()
#   ____________entity: . NET
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "."  and "keterampilan_teknis"  != "B"  order by id asc
#   __________________Total Row(s) : 478
#   __________________round_10_perc Row(s) : 48
#   ____________________[1/478]  #217 __ . __ 0
#   __________________________[1/1]  #218 __ Keuangan __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[48/478]  #19254 __ . __ 0
#   __________________________[1/1]  #19255 __ Business __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[96/478]  #39576 __ . __ 0
#   __________________________[1/1]  #39577 __ Head __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[144/478]  #56600 __ . __ 0
#   __________________________[1/1]  #56601 __ . __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[192/478]  #75049 __ . __ 0
#   __________________________[1/1]  #75050 __ Loc __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[240/478]  #97609 __ . __ 0
#   __________________________[1/1]  #97610 __ com __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[288/478]  #116988 __ . __ 0
#   __________________________[1/1]  #116989 __ Sales __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[336/478]  #132126 __ . __ 0
#   __________________________[1/1]  #132127 __ js __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[384/478]  #148192 __ . __ 0
#   __________________________[1/1]  #148193 __ Cop __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[432/478]  #162092 __ . __ 0
#   __________________________[1/1]  #162093 __ Associate __ nte: NET __ csX: 1 __ lsX: 2
#   __________________
#   __________[20/25]  #385 __ PT Panahome Deltamas __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________dynamic()
#   ____________entity: PT Panahome Deltamas
#   ____________split length: 3
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "PT"  and "perusahaan"  != "B"  order by id asc
#   __________________Total Row(s) : 29
#   __________________round_10_perc Row(s) : 3
#   ____________________[1/29]  #2933 __ PT __ 0
#   __________________________[1/1]  #2934 __ . __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[3/29]  #10506 __ PT __ 0
#   __________________________[1/1]  #10507 __ . __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[6/29]  #27617 __ PT __ 0
#   __________________________[1/1]  #27618 __ . __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[9/29]  #57092 __ PT __ 0
#   __________________________[1/1]  #57093 __ Agel __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[12/29]  #81616 __ PT __ 0
#   __________________________[1/1]  #81617 __ Kalbe __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[15/29]  #93040 __ PT __ 0
#   __________________________[1/1]  #93041 __ Agel __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[18/29]  #104805 __ PT __ 0
#   __________________________[1/1]  #104806 __ Gyoen __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[21/29]  #139460 __ PT __ 0
#   __________________________[1/1]  #139461 __ PERMODALAN __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[24/29]  #143646 __ PT __ 0
#   __________________________[1/1]  #143647 __ . __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[27/29]  #164645 __ PT __ 0
#   __________________________[1/1]  #164646 __ Vivo __ nte: Panahome __ csX: 1 __ lsX: 3
#   __________________
#   __________[21/25]  #386 __ Asisten __ B-Jabatan
#   __________dynamic()
#   ____________entity: Asisten
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `jabatan` = 'B'  where name like "Asisten"
#   __________[22/25]  #387 __ Burger Bangor Group __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________dynamic()
#   ____________entity: Burger Bangor Group
#   ____________split length: 3
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "Burger"  and "perusahaan"  != "B"  order by id asc
#   __________________Total Row(s) : 8
#   __________________round_10_perc Row(s) : 1
#   ____________________[1/8]  #3192 __ Burger __ 0
#   __________________________[1/1]  #3193 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #3194 __ Group __ nte: Group __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 3192 3193 3194  __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________________________________updated_data_dynamic() 3192 __ B-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'B'  WHERE id = 3192
#   __________________________________updated_data_dynamic() 3193 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 3193
#   __________________________________updated_data_dynamic() 3194 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 3194
#   __________________
#   ____________________[2/8]  #11926 __ Burger __ 0
#   __________________________[1/1]  #11927 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #11928 __ Group __ nte: Group __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 11926 11927 11928  __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________________________________updated_data_dynamic() 11926 __ B-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'B'  WHERE id = 11926
#   __________________________________updated_data_dynamic() 11927 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 11927
#   __________________________________updated_data_dynamic() 11928 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 11928
#   __________________
#   ____________________[3/8]  #26640 __ Burger __ 0
#   __________________________[1/1]  #26641 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #26642 __ Group __ nte: Group __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 26640 26641 26642  __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________________________________updated_data_dynamic() 26640 __ B-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'B'  WHERE id = 26640
#   __________________________________updated_data_dynamic() 26641 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 26641
#   __________________________________updated_data_dynamic() 26642 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 26642
#   __________________
#   ____________________[4/8]  #27102 __ Burger __ 0
#   __________________________[1/1]  #27103 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #27104 __ Group __ nte: Group __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 27102 27103 27104  __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________________________________updated_data_dynamic() 27102 __ B-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'B'  WHERE id = 27102
#   __________________________________updated_data_dynamic() 27103 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 27103
#   __________________________________updated_data_dynamic() 27104 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 27104
#   __________________
#   ____________________[5/8]  #37128 __ Burger __ 0
#   __________________________[1/1]  #37129 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #37130 __ Group __ nte: Group __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 37128 37129 37130  __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________________________________updated_data_dynamic() 37128 __ B-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'B'  WHERE id = 37128
#   __________________________________updated_data_dynamic() 37129 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 37129
#   __________________________________updated_data_dynamic() 37130 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 37130
#   __________________
#   ____________________[6/8]  #100813 __ Burger __ 0
#   __________________________[1/1]  #100814 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #100815 __ Admin __ nte: Group __ csX: 2 __ lsX: 3
#   __________________
#   ____________________[7/8]  #106615 __ Burger __ 0
#   __________________________[1/1]  #106616 __ And __ nte: Bangor __ csX: 1 __ lsX: 3
#   __________________
#   ____________________[8/8]  #148903 __ Burger __ 0
#   __________________________[1/1]  #148904 __ Bangor __ nte: Bangor __ csX: 1 __ lsX: 3
#   ________________________________[1/1]  #148905 __ Group __ nte: Group __ csX: 2 __ lsX: 3
#   ________________________________split_ID() 148903 148904 148905  __ B-Perusahaan I-Perusahaan I-Perusahaan
#   __________________________________updated_data_dynamic() 148903 __ B-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'B'  WHERE id = 148903
#   __________________________________updated_data_dynamic() 148904 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 148904
#   __________________________________updated_data_dynamic() 148905 __ I-Perusahaan
#   ____________________________________UPDATE `dataset_jobtitle` SET  `perusahaan` = 'I'  WHERE id = 148905
#   __________________
#   __________[23/25]  #388 __ garment manufacture __ B-pekerjaan_industri I-pekerjaan_industri
#   __________dynamic()
#   ____________entity: garment manufacture
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "garment"  and "pekerjaan_industri"  != "B"  order by id asc
#   __________________Total Row(s) : 44
#   __________________round_10_perc Row(s) : 4
#   ____________________[1/44]  #3836 __ garment __ 0
#   __________________________[1/1]  #3837 __ manufacture __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________________split_ID() 3836 3837  __ B-pekerjaan_industri I-pekerjaan_industri
#   ____________________________updated_data_dynamic() 3836 __ B-pekerjaan_industri
#   ______________________________UPDATE `dataset_jobtitle` SET  `pekerjaan_industri` = 'B'  WHERE id = 3836
#   ____________________________updated_data_dynamic() 3837 __ I-pekerjaan_industri
#   ______________________________UPDATE `dataset_jobtitle` SET  `pekerjaan_industri` = 'I'  WHERE id = 3837
#   __________________
#   ____________________[4/44]  #15711 __ Garment __ 0
#   __________________________[1/1]  #15712 __ ) __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[8/44]  #24390 __ Garment __ 0
#   __________________________[1/1]  #24391 __ Merchandiser __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[12/44]  #32159 __ Garment __ 0
#   __________________________[1/1]  #32160 __ Technician __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[16/44]  #47029 __ Garment __ 0
#   __________________________[1/1]  #47030 __ ) __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[20/44]  #55576 __ Garment __ 0
#   __________________________[1/1]  #55577 __ ( __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[24/44]  #62463 __ Garment __ 0
#   __________________________[1/1]  #62464 __ Manager __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[28/44]  #71591 __ Garment __ 0
#   __________________________[1/1]  #71592 __ Graphic __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[32/44]  #76337 __ Garment __ 0
#   __________________________[1/1]  #76338 __ Assisten __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[36/44]  #104204 __ Garment __ 0
#   __________________________[1/1]  #104205 __ Accounting __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[40/44]  #139965 __ Garment __ 0
#   __________________________[1/1]  #139966 __ ( __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[44/44]  #175657 __ Garment __ 0
#   __________________________[1/1]  #175658 __ Front __ nte: manufacture __ csX: 1 __ lsX: 2
#   __________________
#   __________[24/25]  #389 __ ATOM __ B-Penempatan_gedung
#   __________dynamic()
#   ____________entity: ATOM
#   ____________split length: 1
#   ______________updated_data_single_begining()
#   ________________UPDATE `dataset_jobtitle` SET  `penempatan_gedung` = 'B'  where name like "ATOM"
#   __________[25/25]  #390 __ SULAWESI tengah __ B-Penempatan_provinsi I-Penempatan_provinsi
#   __________dynamic()
#   ____________entity: SULAWESI tengah
#   ____________split length: 2
#   ______________word_0()
#   ________________Select  id  , name  from dataset_jobtitle  where name like "SULAWESI"  and "penempatan_provinsi"  != "B"  order by id asc
#   __________________Total Row(s) : 89
#   __________________round_10_perc Row(s) : 9
#   ____________________[1/89]  #2926 __ Sulawesi __ 0
#   __________________________[1/1]  #2927 __ & __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[9/89]  #9646 __ SULAWESI __ 0
#   __________________________[1/1]  #9647 __ SELATAN __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[18/89]  #26176 __ SULAWESI __ 0
#   __________________________[1/1]  #26177 __ ) __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[27/89]  #37212 __ SULAWESI __ 0
#   __________________________[1/1]  #37213 __ SELATAN __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[36/89]  #50958 __ Sulawesi __ 0
#   __________________________[1/1]  #50959 __ Utara __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[45/89]  #70548 __ SULAWESI __ 0
#   __________________________[1/1]  #70549 __ Apoteker __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[54/89]  #100835 __ Sulawesi __ 0
#   __________________________[1/1]  #100836 __ Tengah __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________________split_ID() 100835 100836  __ B-Penempatan_provinsi I-Penempatan_provinsi
#   ____________________________updated_data_dynamic() 100835 __ B-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'B'  WHERE id = 100835
#   ____________________________updated_data_dynamic() 100836 __ I-Penempatan_provinsi
#   ______________________________UPDATE `dataset_jobtitle` SET  `penempatan_provinsi` = 'I'  WHERE id = 100836
#   __________________
#   ____________________[63/89]  #123750 __ Sulawesi __ 0
#   __________________________[1/1]  #123751 __ ( __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[72/89]  #142409 __ Sulawesi __ 0
#   __________________________[1/1]  #142410 __ Tenggara __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____________________[81/89]  #149422 __ Sulawesi __ 0
#   __________________________[1/1]  #149423 __ & __ nte: tengah __ csX: 1 __ lsX: 2
#   __________________
#   ____End
