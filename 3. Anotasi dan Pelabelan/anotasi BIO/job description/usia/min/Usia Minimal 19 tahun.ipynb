# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    label   = "B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min" 
    update  = "yes" 
    # -------------------------------------------------- 
    wildcard    = "Usia Minimal%"
    length      = 21
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    General_usia_xx_tahun(entity, label, update, wildcard, length, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____General_usia_xx_tahun()
#   ______Select  name   , label   , id   , length   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  and length = 21 and name like 'Usia Minimal%'  order by name asc
#   ________Total Row(s) : 38
#   __________[1/38]  #Usia minimal 18 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '6246';
#   __________[2/38]  #Usia Minimal 18 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '52261';
#   __________[3/38]  #Usia minimal 18 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '61934';
#   __________[4/38]  #usia minimal 18-35 th __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '74436';
#   __________[5/38]  #usia minimal 18-35 th __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '82628';
#   __________[6/38]  #usia minimal 20 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '58688';
#   __________[7/38]  #Usia minimal 20 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '77179';
#   __________[8/38]  #Usia minimal 20 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '87184';
#   __________[9/38]  #Usia minimal 20 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '89693';
#   __________[10/38]  #Usia minimal 21 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '7537';
#   __________[11/38]  #Usia minimal 22 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '7881';
#   __________[12/38]  #Usia minimal 22 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '23052';
#   __________[13/38]  #Usia minimal 22 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '32088';
#   __________[14/38]  #Usia minimal 22 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '33513';
#   __________[15/38]  #Usia minimal 22 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '78609';
#   __________[16/38]  #usia minimal 23 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '12574';
#   __________[17/38]  #Usia minimal 23 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '31127';
#   __________[18/38]  #Usia minimal 23 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '54562';
#   __________[19/38]  #Usia minimal 23 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '59073';
#   __________[20/38]  #Usia minimal 23 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '63568';
#   __________[21/38]  #Usia minimal 24 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '4578';
#   __________[22/38]  #Usia Minimal 24 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '27529';
#   __________[23/38]  #Usia minimal 24 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '53006';
#   __________[24/38]  #Usia minimal 24 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '51068';
#   __________[25/38]  #Usia Minimal 25 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '26220';
#   __________[26/38]  #Usia minimal 25 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '52181';
#   __________[27/38]  #Usia minimal 25 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '60387';
#   __________[28/38]  #Usia minimal 25 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '74204';
#   __________[29/38]  #Usia minimal 25 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '75131';
#   __________[30/38]  #Usia minimal 25 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '84834';
#   __________[31/38]  #Usia Minimal 26 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '97509';
#   __________[32/38]  #Usia Minimal 27 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '23983';
#   __________[33/38]  #Usia minimal 28 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '1574';
#   __________[34/38]  #Usia Minimal 30 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '31509';
#   __________[35/38]  #Usia Minimal 30 Tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '49870';
#   __________[36/38]  #Usia minimal 30 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '57056';
#   __________[37/38]  #Usia minimal 30 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '84246';
#   __________[38/38]  #Usia minimal 35 tahun __ B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min __ 21
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min I-Usia_Min I-Usia_Min', `done` = 1 WHERE `id` = '78265';
