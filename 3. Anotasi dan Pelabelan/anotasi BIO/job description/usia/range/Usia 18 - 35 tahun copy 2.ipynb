# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    label   = "B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max" 
    update  = "yes" 

    # Usia 18 - 35 tahun
    # -------------------------------------------------- 
    wildcard1    = "Usia%"
    wildcard2    = "%-%"
    wildcard3    = "%Tahun"
    length      = 18
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    General_ver3_usia_xx_tahun(entity, label, update, wildcard1, wildcard2, wildcard3, length, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____General_ver3_usia_xx_tahun()
#   ______Select  name   , label   , id   , length   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  and length = 18 and name like 'Usia%'  and name like '%-%'  and name like '%Tahun'  and done is null  order by name asc
#   ________Total Row(s) : 51
#   __________[1/51]  #Usia 18 - 25 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '12410';
#   __________[2/51]  #Usia 18 - 25 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '46444';
#   __________[3/51]  #Usia 18 - 25 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '69214';
#   __________[4/51]  #Usia 18 - 28 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '88716';
#   __________[5/51]  #Usia 18 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '69987';
#   __________[6/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '8056';
#   __________[7/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '23831';
#   __________[8/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '30973';
#   __________[9/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '52786';
#   __________[10/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '51390';
#   __________[11/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '48490';
#   __________[12/51]  #Usia 18 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '56545';
#   __________[13/51]  #Usia 18 - 40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '76075';
#   __________[14/51]  #USIA 18 - 55 TAHUN __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '13913';
#   __________[15/51]  #USIA 18 - 55 TAHUN __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '64268';
#   __________[16/51]  #USIA 18 - 55 TAHUN __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '84472';
#   __________[17/51]  #USIA 18 - 55 TAHUN __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '85101';
#   __________[18/51]  #USIA 18 - 55 TAHUN __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '97130';
#   __________[19/51]  #Usia 19 - 26 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '62994';
#   __________[20/51]  #Usia 19 - 27 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '74515';
#   __________[21/51]  #Usia 20 - 25 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '47323';
#   __________[22/51]  #Usia 20 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '90292';
#   __________[23/51]  #Usia 20 - 33 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '55648';
#   __________[24/51]  #Usia 20 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '9999';
#   __________[25/51]  #Usia 20 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '68001';
#   __________[26/51]  #Usia 20 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '76284';
#   __________[27/51]  #Usia 20 - 37 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '49337';
#   __________[28/51]  #Usia 21 - 30 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '26785';
#   __________[29/51]  #Usia 22 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '20419';
#   __________[30/51]  #Usia 23 - 29 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '45694';
#   __________[31/51]  #Usia 24 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '54595';
#   __________[32/51]  #Usia 24 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '67405';
#   __________[33/51]  #Usia 24 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '78157';
#   __________[34/51]  #Usia 24 - 40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '23201';
#   __________[35/51]  #Usia 25 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '4103';
#   __________[36/51]  #Usia 25 - 30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '51791';
#   __________[37/51]  #Usia 25 - 30 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '79133';
#   __________[38/51]  #Usia 25 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '30752';
#   __________[39/51]  #Usia 25 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '61180';
#   __________[40/51]  #Usia 25 - 35 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '71846';
#   __________[41/51]  #Usia 25 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '77986';
#   __________[42/51]  #Usia 25 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '91695';
#   __________[43/51]  #Usia 25 - 38 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '28784';
#   __________[44/51]  #Usia 27 - 45 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '49075';
#   __________[45/51]  #Usia 28 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '69169';
#   __________[46/51]  #Usia 28 - 40 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '5043';
#   __________[47/51]  #Usia 30 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '80064';
#   __________[48/51]  #usia 30 - 35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '98332';
#   __________[49/51]  #Usia 30 - 40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '11617';
#   __________[50/51]  #Usia 30 - 40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '52611';
#   __________[51/51]  #Usia 35 - 45 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 18
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '59065';
