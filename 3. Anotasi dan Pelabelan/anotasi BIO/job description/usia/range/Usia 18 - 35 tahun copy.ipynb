# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    label   = "B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max" 
    update  = "yes" 

    # Usia 18 - 35 tahun
    # -------------------------------------------------- 
    wildcard1    = "Usia%"
    wildcard2    = "%-%"
    wildcard3    = "%Tahun"
    length      = 16
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    General_ver3_usia_xx_tahun(entity, label, update, wildcard1, wildcard2, wildcard3, length, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____General_ver3_usia_xx_tahun()
#   ______Select  name   , label   , id   , length   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  and length = 16 and name like 'Usia%'  and name like '%-%'  and name like '%Tahun'  and done is null  order by name asc
#   ________Total Row(s) : 54
#   __________[1/54]  #Usia 18-24 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '91092';
#   __________[2/54]  #Usia 18-28 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '91035';
#   __________[3/54]  #Usia 18-29 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '76865';
#   __________[4/54]  #Usia 18-29 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '84896';
#   __________[5/54]  #Usia 18-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '54762';
#   __________[6/54]  #Usia 18-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '63744';
#   __________[7/54]  #Usia 18-60 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '89728';
#   __________[8/54]  #Usia 19-29 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '21849';
#   __________[9/54]  #Usia 19-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '75455';
#   __________[10/54]  #Usia 19-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '83870';
#   __________[11/54]  #Usia 19-36 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '23535';
#   __________[12/54]  #Usia 20-25 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '13940';
#   __________[13/54]  #Usia 20-25 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '18201';
#   __________[14/54]  #Usia 20-27 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '2800';
#   __________[15/54]  #Usia 20-27 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '71426';
#   __________[16/54]  #Usia 20-27 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '77474';
#   __________[17/54]  #Usia 20-27 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '80391';
#   __________[18/54]  #Usia 20-28 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '89402';
#   __________[19/54]  #Usia 20-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '4681';
#   __________[20/54]  #Usia 20-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '52345';
#   __________[21/54]  #Usia 20-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '62760';
#   __________[22/54]  #Usia 20-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '20761';
#   __________[23/54]  #Usia 20-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '21810';
#   __________[24/54]  #Usia 20-35 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '55787';
#   __________[25/54]  #Usia 21-28 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '87974';
#   __________[26/54]  #Usia 21-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '48807';
#   __________[27/54]  #Usia 22-27 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '88928';
#   __________[28/54]  #Usia 22-28 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '7546';
#   __________[29/54]  #Usia 22-30 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '2486';
#   __________[30/54]  #Usia 22-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '10816';
#   __________[31/54]  #Usia 22-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '32178';
#   __________[32/54]  #Usia 23-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '8964';
#   __________[33/54]  #Usia 23-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '98441';
#   __________[34/54]  #Usia 23-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '10413';
#   __________[35/54]  #Usia 23-35 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '56509';
#   __________[36/54]  #Usia 24-28 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '77278';
#   __________[37/54]  #Usia 24-45 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '77080';
#   __________[38/54]  #Usia 25-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '12270';
#   __________[39/54]  #Usia 25-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '92373';
#   __________[40/54]  #Usia 25-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '316';
#   __________[41/54]  #Usia 25-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '5128';
#   __________[42/54]  #Usia 25-35 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '30581';
#   __________[43/54]  #Usia 25-35 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '50209';
#   __________[44/54]  #Usia 25-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '82355';
#   __________[45/54]  #Usia 26-40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '52896';
#   __________[46/54]  #Usia 27-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '97316';
#   __________[47/54]  #USIA 28-35 TAHUN __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '29993';
#   __________[48/54]  #Usia 29-30 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '87438';
#   __________[49/54]  #Usia 30-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '2306';
#   __________[50/54]  #Usia 30-35 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '84691';
#   __________[51/54]  #Usia 30-40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '84276';
#   __________[52/54]  #Usia 30-40 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '89789';
#   __________[53/54]  #Usia 30-45 Tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '52434';
#   __________[54/54]  #Usia 40-50 tahun __ B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max __ 16
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Min I-Usia_Min B-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '30727';
