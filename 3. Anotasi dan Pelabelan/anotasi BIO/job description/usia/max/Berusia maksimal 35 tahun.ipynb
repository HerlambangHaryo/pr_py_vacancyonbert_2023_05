# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    label   = "B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max" 
    update  = "yes" 
    # -------------------------------------------------- 
    wildcard    = "Berusia Maksimal%"
    length      = 25
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    General_usia_xx_tahun(entity, label, update, wildcard, length, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____General_usia_xx_tahun()
#   ______Select  name   , label   , id   , length   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  and length = 25 and name like 'Berusia Maksimal%'  order by name asc
#   ________Total Row(s) : 28
#   __________[1/28]  #Berusia maksimal 25 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '98503';
#   __________[2/28]  #Berusia maksimal 28 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '22518';
#   __________[3/28]  #Berusia maksimal 28 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '58402';
#   __________[4/28]  #Berusia maksimal 29 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '27490';
#   __________[5/28]  #Berusia maksimal 29 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '67886';
#   __________[6/28]  #Berusia maksimal 30 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '15713';
#   __________[7/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '51153';
#   __________[8/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '64709';
#   __________[9/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '73784';
#   __________[10/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '77035';
#   __________[11/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '77056';
#   __________[12/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '87292';
#   __________[13/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '88617';
#   __________[14/28]  #Berusia maksimal 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '96751';
#   __________[15/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '4124';
#   __________[16/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '6693';
#   __________[17/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '10453';
#   __________[18/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '14509';
#   __________[19/28]  #Berusia maksimal 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '28343';
#   __________[20/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '33864';
#   __________[21/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '91960';
#   __________[22/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '92818';
#   __________[23/28]  #Berusia maksimal 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '93845';
#   __________[24/28]  #Berusia Maksimal 37 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '32021';
#   __________[25/28]  #Berusia maksimal 37 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '82294';
#   __________[26/28]  #Berusia Maksimal 40 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '2260';
#   __________[27/28]  #Berusia Maksimal 40 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '2554';
#   __________[28/28]  #Berusia Maksimal 45 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 25
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '56144';
