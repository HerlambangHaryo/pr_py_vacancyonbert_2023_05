# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    label   = "B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max" 
    update  = "yes" 
    # -------------------------------------------------- 
    wildcard    = "Usia Max%"
    length      = 17
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    General_usia_xx_tahun(entity, label, update, wildcard, length, space)
    # --------------------------------------------------    
    ####################################################  ##
# Out:
#   ____General_usia_xx_tahun()
#   ______Select  name   , label   , id   , length   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  and length = 17 and name like 'Usia Max%%'  order by name asc
#   ________Total Row(s) : 33
#   __________[1/33]  #usia max 25 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '1532';
#   __________[2/33]  #Usia max 25 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '15597';
#   __________[3/33]  #Usia Max 25 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '56023';
#   __________[4/33]  #usia max 25 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '93366';
#   __________[5/33]  #Usia max 25 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '94120';
#   __________[6/33]  #usia max 26 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '26971';
#   __________[7/33]  #Usia max 27 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '80834';
#   __________[8/33]  #Usia max 27 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '93700';
#   __________[9/33]  #Usia Max 30 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '16830';
#   __________[10/33]  #Usia Max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '19840';
#   __________[11/33]  #Usia max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '53925';
#   __________[12/33]  #Usia max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '54671';
#   __________[13/33]  #Usia max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '57936';
#   __________[14/33]  #Usia max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '62882';
#   __________[15/33]  #Usia max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '73409';
#   __________[16/33]  #Usia max 30 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '90164';
#   __________[17/33]  #Usia max 32 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '15151';
#   __________[18/33]  #Usia Max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '21252';
#   __________[19/33]  #Usia Max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '26206';
#   __________[20/33]  #Usia Max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '51693';
#   __________[21/33]  #Usia Max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '51333';
#   __________[22/33]  #Usia Max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '49891';
#   __________[23/33]  #Usia max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '47004';
#   __________[24/33]  #Usia max 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '57306';
#   __________[25/33]  #Usia max 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '64139';
#   __________[26/33]  #Usia max 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '72341';
#   __________[27/33]  #usia Max 35 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '85072';
#   __________[28/33]  #Usia Max 35 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '87702';
#   __________[29/33]  #Usia max 38 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '95345';
#   __________[30/33]  #Usia max 40 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '94093';
#   __________[31/33]  #Usia max 45 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '29055';
#   __________[32/33]  #Usia max 45 tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '47988';
#   __________[33/33]  #Usia max 45 Tahun __ B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max __ 17
#   __________pelabelan()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `label` = 'B-Usia_Max I-Usia_Max I-Usia_Max I-Usia_Max', `done` = 1 WHERE `id` = '55671';
