# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    lihat_data_usia(entity, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____lihat_data_usia()
#   ______Select  name   , label   , id   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  and done is null  order by name asc
#   ________Total Row(s) : 1132
#   __________[1/1132]  # Usia maksimal 28 tahun __ O O O O O O
#   __________[2/1132]  #-             Usia max 30 tahun __ O O O O
#   __________[3/1132]  #-        Usia Maksimal 30 Tahun __ O O O O O O
#   __________[4/1132]  #-  Usia 18 - 40 tahun __ O O O O O O
#   __________[5/1132]  #- Berusia 20-40 Tahun __ O O O O
#   __________[6/1132]  #- Berusia 21 tahun ke atas __ O O O O O O
#   __________[7/1132]  #﻿- Berusia maksimal 35 tahun untuk lulusan S2, dan 40 tahun untuk lulusan S3 __ O O O O O O O O O O O O O O
#   __________[8/1132]  #- Berusia minimal 19 tahun __ O O O O O
#   __________[9/1132]  #- Maksimal usia 30 tahun __ O O O O O
#   __________[10/1132]  #- usia 19 - 27 tahun __ O O O O O O
#   __________[11/1132]  #- usia max 25 tahun __ O O O O O
# ...
