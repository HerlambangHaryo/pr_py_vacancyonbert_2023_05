# %%
# Import
import sys
sys.path.append('../../../../../')
 
from a_models.usia import *   
 
if __name__ == '__main__': 
    # --------------------------------------------------  
    entity  = "jobdescription_dataset_0_5000_fk_train"  
    # -------------------------------------------------- 
    space = "  __" 
    # --------------------------------------------------  
    bukan_usia(entity, space)
    # --------------------------------------------------    
    ####################################################
# Out:
#   ____bukan_usia()
#   ______Select  name   , id   from jobdescription_dataset_0_5000_fk_train where entitas = 'Usia'  order by name asc
#   ________Total Row(s) : 1354
#   __________[1/1354]  __INT__  # Usia maksimal 28 tahun
#   __________[2/1354]  __INT__  #              Usia max 30 tahun
#   __________[3/1354]  __INT__  #         Usia Maksimal 30 Tahun
#   __________entitas_back_to_null()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `entitas` = '' WHERE `id` = '61220';
#   __________[4/1354]  __NOT__  #        Usia max
#   __________entitas_back_to_null()
#   ____________UPDATE `jobdescription_dataset_0_5000_fk_train` SET `entitas` = '' WHERE `id` = '85751';
#   __________[5/1354]  __NOT__  #       Usia max
#   __________[6/1354]  __INT__  #   Usia 18   40 tahun
#   __________[7/1354]  __INT__  #  Berusia 20 40 Tahun
#   __________[8/1354]  __INT__  #  Berusia 21 tahun ke atas
# ...
